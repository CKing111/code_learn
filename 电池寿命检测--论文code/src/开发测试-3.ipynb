# %% [markdown]
# # 构建目标检测主干框架代码

# %%
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
import tensorflow as tf
# from spektral.layers import GraphConv
from tensorflow.keras.models import Model # Sequential, Model
from tensorflow.keras.layers import * # Dense, Dropout, BatchNormalization, LSTM, Conv1D, Flatten, GRU, Input
from tensorflow.keras import optimizers, regularizers


def build_model(input_seq_len=132, 
                output_seq_len=64,
                losss='mse',
                optimizerr='adam'
               ):
        
    # inputs
    Feature_inputs = L.Input(shape=(input_seq_len, 4356), name="Feature_inputs")
    Feature_inputs2 = L.Input(shape=(input_seq_len, 33), name="Feature_inputs2")

    Feature_inputs_new = L.Dense(660)(Feature_inputs)
    Feature_inputs_new2 = L.Dense(64)(Feature_inputs2)

    conv_1 = L.Conv1D(
        16, 1,
        padding='same',name="conv_1")(Feature_inputs_new)
    conv_1_1 = L.LeakyReLU()(conv_1)

    conv_2 = L.Conv1D(
        16,3,
        padding='same',name="conv_2")(Feature_inputs_new)
    conv_2_2 = L.LeakyReLU()(conv_2)

    
    conv_3 = L.Conv1D(
        16,4,
        padding='same',name="conv_3")(Feature_inputs_new)
    conv_3_3 = L.LeakyReLU()(conv_3)



    LSTM1 = L.Bidirectional(LSTM(16,input_shape=(input_seq_len,660),return_sequences=True,name='LSTM1'))(Feature_inputs_new)
    
    merged_vector = concatenate([conv_1_1, conv_2_2, conv_3_3, LSTM1], axis=-1,name="merged_vector")
    LSTM2 = L.Bidirectional(LSTM(16,name='LSTM2'))(merged_vector)
    Flatten1 = Flatten(name="Flatten1")(LSTM2)
    Dense2 = Dense(16, activation='sigmoid',name="Dense2")(Flatten1)
    out1 = Dense(1, activation='sigmoid',name="out1")(Dense2)
    
    Flatten2 = Flatten()(Feature_inputs2)
    Dense2 = Dense(16)(Flatten2)
    out2 = Dense(1,name='out2')(Dense2)
    
    merged_vector2 = concatenate([out1, out2], axis=-1,name="merged_vector2")
    out3 = Dense(1, activation='sigmoid',name="out3")(merged_vector2)
    
    model = Model(
        inputs=[
            Feature_inputs,Feature_inputs2
        ],
        outputs=out3,
    )
    model.compile(loss=losss,
                  optimizer=optimizerr,
#                   optimizer=optimizers.Adam(lr=0.004,decay=0.04), 
                  metrics=['accuracy'])
    model.summary()
    return model

model = build_model(input_seq_len=10, 
                output_seq_len=64,
                losss='mse',
                optimizerr='adam')
tf.keras.utils.plot_model(model,to_file='1.png',show_shapes=True,show_layer_names=True)
# Out:
# Model: "model_26"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Feature_inputs (InputLayer)     [(None, 10, 4356)]   0
# __________________________________________________________________________________________________
# dense_62 (Dense)                (None, 10, 660)      2875620     Feature_inputs[0][0]
# __________________________________________________________________________________________________
# conv_1 (Conv1D)                 (None, 10, 16)       10576       dense_62[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv1D)                 (None, 10, 16)       31696       dense_62[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv1D)                 (None, 10, 16)       42256       dense_62[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 10, 16)       0           conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 10, 16)       0           conv_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 10, 16)       0           conv_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_29 (Bidirectional (None, 10, 32)       86656       dense_62[0][0]
# __________________________________________________________________________________________________
# merged_vector (Concatenate)     (None, 10, 80)       0           leaky_re_lu_49[0][0]
#                                                                  leaky_re_lu_50[0][0]
#                                                                  leaky_re_lu_51[0][0]
#                                                                  bidirectional_29[0][0]
# __________________________________________________________________________________________________
# bidirectional_30 (Bidirectional (None, 32)           12416       merged_vector[0][0]
# __________________________________________________________________________________________________
# Feature_inputs2 (InputLayer)    [(None, 10, 33)]     0
# __________________________________________________________________________________________________
# Flatten1 (Flatten)              (None, 32)           0           bidirectional_30[0][0]
# __________________________________________________________________________________________________
# flatten_15 (Flatten)            (None, 330)          0           Feature_inputs2[0][0]
# __________________________________________________________________________________________________
# Dense2 (Dense)                  (None, 16)           528         Flatten1[0][0]
# __________________________________________________________________________________________________
# dense_64 (Dense)                (None, 16)           5296        flatten_15[0][0]
# __________________________________________________________________________________________________
# out1 (Dense)                    (None, 1)            17          Dense2[0][0]
# __________________________________________________________________________________________________
# out2 (Dense)                    (None, 1)            17          dense_64[0][0]
# __________________________________________________________________________________________________
# merged_vector2 (Concatenate)    (None, 2)            0           out1[0][0]
#                                                                  out2[0][0]
# __________________________________________________________________________________________________
# out3 (Dense)                    (None, 1)            3           merged_vector2[0][0]
# ==================================================================================================
# Total params: 3,065,081
# Trainable params: 3,065,081
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import numpy as np
import random
import math
import os
import scipy.io
from scipy.io import loadmat
import scipy
from datetime import datetime
import matplotlib.pyplot as plt


import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
# %matplotlib inline

from math import sqrt
from datetime import datetime
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

import tensorflow as tf
print(tf.__version__)
from tensorflow.keras import * 
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))   #打印gpu信息
import os 
os.environ["CUDA_VISIBLE_DEVICES"]="0"
# Out:
# 1.15.0
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device

# %%
# data
# https://github.com/XiuzeZhou/NASA/blob/main/RNN%20%26%20LSTM.ipynb

# 转换时间格式，将字符串转换成 datatime 格式
def convert_to_time(hmm):
    year, month, day, hour, minute, second = int(hmm[0]), int(hmm[1]), int(hmm[2]), int(hmm[3]), int(hmm[4]), int(hmm[5])
    return datetime(year=year, month=month, day=day, hour=hour, minute=minute, second=second)

# 加载 mat 文件
def loadMat(matfile):
    data = scipy.io.loadmat(matfile)  # 加载mat文件
    filename = matfile.split("/")[-1].split(".")[0]  # 以‘.’和‘/’为分隔符分割，分割出路径中的文件名
            # nasa_count_data/B0006.mat  ---》  B0006
    col = data[filename]  # dict_keys(['__header__', '__version__', '__globals__', 'B0006'])
    col = col[0][0][0][0]  # numpy   (1, 1 )  --->  (616,)  
    size = col.shape[0]

    data = []
    for i in range(size):
#         print(col.shape)
        k = list(col[i][3][0].dtype.fields.keys()) 
        # k:dict_keys(['Voltage_measured', 'Current_measured', 'Temperature_measured', 
                        #'Current_charge', 'Voltage_charge', 'Time'])
        # “电压测量”、“电流测量”、“温度测量”、“电流充电”、“电压充电”、“时间”
        # col[i][0][0]  : 表示当前样本i的作业类别，放电、充电、阻抗
        # col[i][1][0]  : 表示当前样本i的作业温度
        # col[i][2][0]  : 表示当前样本i的作业日期，时间，'2008-04-02 13:08:17'
        # col[i][3][0]  : 表示当前样本i的作业六个参数值
        
        d1, d2 = {}, {}
        if str(col[i][0][0]) != 'impedance': # 判断作业类型,非阻抗作业
            for j in range(len(k)):          # 遍历六个特征列
                t = col[i][3][0][0][j][0];
                l = [t[m] for m in range(len(t))]
                d2[k[j]] = l                 # 将读取到的数据放入对应的字典keys下
        d1['type'], d1['temp'] = str(col[i][0][0]), int(col[i][1][0])
        d1['time'], d1['data'] = str(convert_to_time(col[i][2][0])), d2
        data.append(d1)
    return data

# 提取锂电池容量
def getBatteryCapacity(Battery):
    # 电池容量在放电数据集 'discharge'的'Capacity'特征下；
    cycle, capacity = [], []
    i = 1
    for Bat in Battery:
        if Bat['type'] == 'discharge':
            capacity.append(Bat['data']['Capacity'][0])
            cycle.append(i)
            i += 1
    return [cycle, capacity]  # 构成了(x, y)坐标系


# 获取锂电池充电或放电时的测试数据
def getBatteryValues(Battery, Type='charge'):
    data=[]
    for Bat in Battery:
        if Bat['type'] == Type:
            data.append(Bat['data'])
    return data

# 检查样本列表中个样本的数据量
def samples_nums(Battery_list,dir_path,filetype='.mat'):
    for name in Battery_list:
        path = dir_path + name + filetype
        data = loadMat(path)
        python_y=np.array(data) #将matlab数据赋值给python变量
        c, d, im = 0, 0, 0
        for i in range(0,len(python_y)):
            if python_y[i]['type']=='charge': c+=1
            if python_y[i]['type']=='discharge': d+=1
            if python_y[i]['type']=='impedance': im+=1
        print('样本%s，总样本数：'%name,python_y.shape[0],
              '， 冲电记录次数：',c,'， 放电记录次数：',d,'， 阻抗记录次数：',im)

# 获取列表样本对应的电池数据     
def Battery_Data(Battery_list,dir_path):
    capacity, charge, discharge = {}, {}, {}
    for name in Battery_list:
        print('Load Dataset ' + name + '.mat ...')
        path = dir_path + name + '.mat'
        data = loadMat(path)
        print(len(data))
        capacity[name] = getBatteryCapacity(data)              # 放电时的容量数据
        charge[name] = getBatteryValues(data, 'charge')        # 充电数据
        discharge[name] = getBatteryValues(data, 'discharge')  # 放电数据
    return capacity, charge, discharge

# 作图，同样本数据对比图
def plot_Comparison(samples_name, data, list_name, color_list,x_ax=None,y_ax=None, unit=None, label=None):
    if samples_name!=None:
        # 单样本数据画图比对
        fig, ax = plt.subplots(1, figsize=(12, 8))
        c = 0
        for t,color in zip(list_name, color_list):
            Battery = data[samples_name][t]
            ax.plot(Battery[x_ax], Battery[y_ax], color, label='%s time: '%label+str(t))
            c += 1
        ax.set(xlabel=x_ax, ylabel=y_ax.split("_")[0] + ' (%s)'%unit, title='%s Curve'%label)
        plt.legend()
    plt.savefig('NASA-05-018-%s-%s.png'%(label,y_ax.split("_")[0]))

# %%
# 路径，样本列表
dir_path = "nasa_count_data/"
Battery_list0 = [
                'B0005', 'B0006', 'B0007', 'B0018',
               'B0025', 'B0026', 'B0027', 'B0028',
               'B0029', 'B0030', 'B0031', 'B0032',
               'B0033', 'B0034', 'B0036', 'B0038',
               'B0039', 'B0040', 'B0041', 'B0042',
               'B0043', 'B0044', 'B0045', 'B0046',
               'B0047', 'B0048', 'B0049', 
#                'B0050',
#                'B0051',
#                'B0052', 
#                 'B0053', 'B0054',
#                'B0055', 'B0056'
                ]
Battery_list = ['B0005', 'B0006', 'B0007', 'B0018']

# 检查数据个数，获取样本电池数据
# samples_nums(Battery_list0,dir_path,'.mat')     
capacity, charge, discharge = Battery_Data(Battery_list0,dir_path)
# Out:
# Load Dataset B0005.mat ...
# 616
# Load Dataset B0006.mat ...
# 616
# Load Dataset B0007.mat ...
# 616
# Load Dataset B0018.mat ...
# 319
# Load Dataset B0025.mat ...
# 80
# Load Dataset B0026.mat ...
# 80
# Load Dataset B0027.mat ...
# 80
# Load Dataset B0028.mat ...
# 80
# Load Dataset B0029.mat ...
# 97
# Load Dataset B0030.mat ...
# 97
# Load Dataset B0031.mat ...
# 97
# Load Dataset B0032.mat ...
# 97
# Load Dataset B0033.mat ...
# 486
# Load Dataset B0034.mat ...
# 486
# Load Dataset B0036.mat ...
# 486
# Load Dataset B0038.mat ...
# 122
# Load Dataset B0039.mat ...
# 122
# Load Dataset B0040.mat ...
# 122
# Load Dataset B0041.mat ...
# 163
# Load Dataset B0042.mat ...
# 275
# Load Dataset B0043.mat ...
# 275
# Load Dataset B0044.mat ...
# 275
# Load Dataset B0045.mat ...
# 184
# Load Dataset B0046.mat ...
# 184
# Load Dataset B0047.mat ...
# 184
# Load Dataset B0048.mat ...
# 184
# Load Dataset B0049.mat ...
# 62

# %%
len(Battery_list0)
# Out:
# 27

# %%
print(len(discharge['B0005'][167]['Time']))
# Out:
# 300

# %%
# 3. 容量 v.s. 充放电次数 曲线


fig, ax = plt.subplots(1, figsize=(12, 8))
color_list = ['b:', 'g--', 'r-.', 'c+']
c = 0
for name,color in zip(Battery_list, color_list):
    df_result = capacity[name]  # （循环次数， 当前容量）坐标
    ax.plot(df_result[0], df_result[1], color, label=name)
ax.set(xlabel='Discharge cycles', ylabel='Capacity (Ah)', title='Capacity degradation at ambient temperature of 24°C')
plt.legend()
plt.savefig('NASA-05-018-Capacity.png')

# %%
# 4. 充电电流 v.s. 充电时间 曲线
name = 'B0005'       #查看的电池号
time = [0, 50, 100, 150] #查看的充电次数
color_list = ['b', 'g', 'r', 'c']
plot_Comparison(samples_name=name, data=charge, 
                list_name=time, color_list=color_list, 
                x_ax='Time', y_ax='Current_measured', unit='A', label='Charging')
# 5. 放电电压 v.s. 充电时间 曲线
time_d = [0, 50, 100, 150]     #查看的放电次数
color_list_d = ['b', 'g', 'r', 'c']
plot_Comparison(samples_name=name, data=discharge, 
                list_name=time_d, color_list=color_list_d, 
                x_ax='Time', y_ax='Voltage_measured', unit='V',label='Discharging')

# %%
# 数据集打包模块
# 打包当前sheet序列数据和标签
# 重叠打包策略
def createXY(dataset,n_past):
    """
        dataset：传入数据集；
        n_past：lstm的timestep，预测下一个目标值时将在过去查看的步骤数；
        index: 预测目标标签；
        trainX — — →trainY
        eg：
            [0 : 30,0:5] → [30,0]
            [1:31, 0:5] → [31,0]
            [2:32,0:5] →[32,0]
    """
#     print(dataset.shape,dataset.shape[1])
    n_past=int(n_past)
#     index=int(index)
    dataX = [] # 所有的特征值
    dataY = [] # 目标预测标签

#     print(len(dataset),dataset[168])
    for i in range(n_past, len(dataset)):
#         print()
        if i<len(dataset):
            dataX.append(dataset[i - n_past:i])
            dataY.append(dataset[i])
        else:
            break
    return np.array(dataX),np.array(dataY)


def build_sequences(text, window_size):
    #text:list of capacity
    x, y = [],[]
    for i in range(window_size,len(text)):  # 【window_size:-1】
        if i<len(text):
            sequence = text[i - window_size:i]      # 特征
            target = text[i]    # 标签,延后的序列。。。？？？

            x.append(sequence)
            y.append(target)
        else:
            break
        
    return np.array(x), np.array(y)

def get_train_test(data_dict, window_size=8, test_num=20):
    # 余下数据生成训练集
    x, y, x_test, y_test = [], [], [], []
    count = 0
    for k, v in data_dict.items():  # 返回可遍历的(键, 值) 元组数组，然后便利， k:样本名， v:样本对应数据（容量）
        data_x, data_y = build_sequences(text=v[1], window_size=window_size)
        data_x0, data_y0 = data_x[0:-test_num], data_y[0:-test_num]
        data_x1, data_y1 = data_x[-test_num:], data_y[-test_num:]
        if count==0:
            x, y = data_x0, data_y0
            x_test, y_test = data_x1, data_y1
        else:
            x, y = np.r_[x, data_x0], np.r_[y, data_y0]
            x_test, y_test = np.r_[x_test, data_x1], np.r_[y_test, data_y1]
                            # np.r_：是按列连接两个矩阵，就是把两矩阵上下相加，要求列数相等，类似于pandas中的concat()。
                            # np.c_：是按行连接两个矩阵，就是把两矩阵左右相加，要求行数相等，类似于pandas中的merge()。
        count+=1
    return x, y, x_test, y_test

def shuffle_data(X,y):
    # shuffle数据集
    # X,y: 数据集样本和标签
    # return：shuffle后的特征和标签，以及打乱后的索引
    data_list=np.array(X)           # list of images
    label_list=np.array(y)           # list of labels

    ##如果image_list存的是读取的特征数据，而不是图片路径，不要注释后面两句（list无法索引内部list）
    #[list indices must be integers or slices, not list]
    #image_list = np.array(image_list)
    #label_list = np.array(label_list)

    index = [i for i in range(len(data_list))]
    np.random.shuffle(index)
    data = data_list[index]
    labels = label_list[index]
    return data, labels, index

# 获取所有样本列元素极值，用于归一化尺度
# def sheet_extreme(data,sheet_nums,category='regression'):
    
    
# 多维根据normalize归一化Positive / 反归一化negative
def NormalizeMult_1(data,normalize, type='Positive'):
    # 数据， 极值列表
    data = np.array(data)
    listlow = normalize[0][0]
    listhigh = normalize[0][1]
    delta = listhigh - listlow
    for i in range(0,data.shape[0]):
        if delta != 0:
            if type=='Positive':
                    data[i]  =  (data[i] - listlow)/delta                  
            elif type=='Negative':
                    data[i]  =  data[i]*delta + listlow
                    
    
    
    
#     for i in range(0,data.shape[1]):
#         listlow = normalize[i,0]
#         listhigh = normalize[i,1]
#         delta = listhigh - listlow
#         if delta != 0:
#             for j in range(0,data.shape[0]):
#                 if type=='Positive':
#                     data[j,i]  =  (data[j,i] - listlow)/delta                  
#                 elif type=='Negative':
#                     data[j,i]  =  data[j,i]*delta + listlow
    return  data


# 获取所有样本列元素极值，用于归一化尺度
def sheet_extreme(data,category='1'):
    
    # 声明一个初始化极值标签列表，取自样本
    if  category=='4':
        normalize_end = np.array( [[4.5358, 9.3226],
                                 [0.0000, 1.6654],
                                 [4.8653, 1.0000],
                                 [0.0000, 1.0000]])
    elif category=='3':
        normalize_end = np.array( [[4.5358, 9.3226],
                                  [0.0000, 1.6654],
                                  [0.0000, 1.6654]])         
    elif category=='2':
        normalize_end = np.array( [[4.5358, 9.3226],
                                 [0.0000, 1.6654]])  
    elif category=='1':
        normalize_end = np.array( [[4.5358, 9.3226]])  
        
    for i in range(0,data.shape[1]): # 遍历列
        #第i列数据
        listt = data[:,i]
        # 获得目标列极值
        listlow,listhigh =  np.percentile(listt, [0, 100])
        # 存储目标列极值
        normalize_end[i,0] = listlow
        normalize_end[i,1] = listhigh
    print('end_normalize:\n',normalize_end)
    return normalize_end
        
from functools import partial
def flatten(x):
    # 上面这个 flatten 函数有两个返回值，一个是拉平后的 1 维数组，第二个是恢复原来形状的函数
    # a2,unflatten = flatten(a1), unflatten(a2) = a1
    original_shape = x.shape
    return x.flatten(), partial(np.reshape, newshape=original_shape)


from sklearn.preprocessing import MinMaxScaler
# 数据归一化
def Fit_transform(raw_data,a,b):
    # 数据归一化
    scaler = MinMaxScaler(feature_range=(a, b))
    return scaler.fit_transform(raw_data), scaler
def Inverse_transform(raw_data,scaler):
    # 将标准化后的数据转换为原始数据（反归一化）
    return scaler.inverse_transform(raw_data)

# %%
# CNN1D模型三特征
def build_model_cnn1d(optimizer):
    input_data_full = Input(shape=(16,1), name='input_data_full')
    # 1分支
    cnn_out = Conv1D(filters=64, kernel_size=8, 
                     activation='relu',padding='same', input_shape=(16,1),name="cnn_out")(input_data_full)
    Flatten2 = Flatten(name="Flatten2")(cnn_out)
    Dense2 = Dense(50, activation='sigmoid',name="Dense2")(Flatten2)
    predictions1 = Dense(1, activation='sigmoid',name="predictions1")(Dense2)
    inputs = [input_data_full]
    model = Model(inputs, predictions1)  ####
    model.compile(optimizer=optimizer, loss='mse', metrics=['accuracy'])
    model.summary()
    x = 'CNN1D'
    return model,x

# LSTM
def build_model_LSTM(optimizer):
    input_data_full = Input(shape=(16,1), name='input_data_full')
    LSTM1 = LSTM(64,input_shape=(16,1),return_sequences=True,name='LSTM1')(input_data_full)
    LSTM2 = LSTM(64,name='LSTM2')(LSTM1)
    Flatten1 = Flatten(name="Flatten1")(LSTM2)
    predictions1 = Dense(1, activation='sigmoid',name="predictions1")(Flatten1)
    inputs = [input_data_full]
    model = Model(inputs, predictions1)  ####    
    model.compile(loss='mse',
                  optimizer=optimizer,
#                   optimizer=optimizers.Adam(lr=0.004,decay=0.04), 
                  metrics=['accuracy'])
    model.summary()
    x = 'LSTM2'
    return model,x
def build_model_LSTM1(optimizer):
    input_data_full = Input(shape=(16,1), name='input_data_full')
    LSTM1 = LSTM(64,input_shape=(16,1),return_sequences=True,name='LSTM1')(input_data_full)
    Flatten1 = Flatten(name="Flatten1")(LSTM1)
    predictions1 = Dense(1, activation='sigmoid',name="predictions1")(Flatten1)
    inputs = [input_data_full]
    model = Model(inputs, predictions1)  ####    
    model.compile(loss='mse',
                  optimizer=optimizer,
#                   optimizer=optimizers.Adam(lr=0.004,decay=0.04), 
                  metrics=['accuracy'])
    model.summary()
    x = 'LSTM1'
    return model,x

# GRU
def build_model_GRU(optimizer):
    input_data_full = Input(shape=(16,1), name='input_data_full')
    GRU1 = GRU(16,input_shape=(16,1),return_sequences=True,name='GRU1')(input_data_full)
    GRU2 = GRU(16,return_sequences=True,name='GRU2')(GRU1)
    GRU3 = GRU(16,name='GRU3')(GRU2)
    Flatten1 = Flatten(name="Flatten1")(GRU3)
    predictions1 = Dense(1, activation='sigmoid',name="predictions1")(Flatten1)
    inputs = [input_data_full]
    model = Model(inputs, predictions1)  ####    
    model.compile(loss='mse',
                  optimizer=optimizer,
#                   optimizer=optimizers.Adam(lr=0.004,decay=0.04), 
                  metrics=['accuracy'])
    model.summary()
    x = 'GRU3'
    return model,x

def build_model_CNN_LR(optimizer):
    # 定义输入
    input_data_sm = Input(shape=(16,1), name='input_data_sm')
    input_data_wh_V = Input(shape=(16,1), name='input_data_wh_V')
    # LR分支
    Flatten1 = Flatten(name="Flatten1")(input_data_sm)
    predictions0 = Dense(1, activation='sigmoid',name="predictions0")(Flatten1)
    # CNN分支
    cnn_out = Conv1D(filters=16, kernel_size=8, activation='relu',padding='same', 
                     input_shape=(16, 1),name="cnn_out")(input_data_wh_V)
    Flatten2 = Flatten(name="Flatten2")(cnn_out)
    Dense2 = Dense(16, activation='sigmoid',name="Dense2")(Flatten2)
    predictions1 = Dense(1, activation='sigmoid',name="predictions1")(Dense2)
    # 合并向量：
    merged_vector = concatenate([predictions0, predictions1], axis=-1,name="merged_vector")
    Dense3 = Dense(16, activation='sigmoid',name="Dense3")(merged_vector)
    predictions2 = Dense(1, activation='sigmoid',name="predictions2")(Dense3)
    inputs = [input_data_sm,input_data_wh_V]
    model = Model(inputs, predictions2)  
    model.compile(optimizer=optimizer, loss='mse', metrics=['accuracy'])
    model.summary()
    x = "CNN1D_LR"
    return model,x

def build_model_CNN_CNN(optimizer):
    # 定义输入
    input_data_sm = Input(shape=(16,1), name='input_data_sm')
    input_data_wh_V = Input(shape=(16,1), name='input_data_wh_V')
    # CNN-1分支
    cnn_out0 = Conv1D(filters=16, kernel_size=8, activation='relu',padding='same', 
                     input_shape=(16, 1),name="cnn_out0")(input_data_sm)
    Flatten1 = Flatten(name="Flatten1")(cnn_out0)
    predictions0 = Dense(1, activation='sigmoid',name="predictions0")(Flatten1)
    # CNN-2分支
    cnn_out = Conv1D(filters=16, kernel_size=8, activation='relu',padding='same', 
                     input_shape=(16, 1),name="cnn_out")(input_data_wh_V)
    Flatten2 = Flatten(name="Flatten2")(cnn_out)
    Dense2 = Dense(16, activation='sigmoid',name="Dense2")(Flatten2)
    predictions1 = Dense(1, activation='sigmoid',name="predictions1")(Dense2)
    # 合并向量：
    merged_vector = concatenate([predictions0, predictions1], axis=-1,name="merged_vector")
    Dense3 = Dense(16, activation='sigmoid',name="Dense3")(merged_vector)
    predictions2 = Dense(1, activation='sigmoid',name="predictions2")(Dense3)
    inputs = [input_data_sm,input_data_wh_V]
    model = Model(inputs, predictions2)  
    model.compile(optimizer=optimizer, loss='mse', metrics=['accuracy'])
    model.summary()
    x = "CNN1D_CNN1D"
    return model,x

def build_model_CNN_LSTM(optimizer):
    # 定义输入
    input_data_1 = Input(shape=(16,1), name='input_data_sm')
    input_data_2 = Input(shape=(16,1), name='input_data_wh_V')
    # CNN-1分支
    LSTM1 = LSTM(64,input_shape=(16,1),return_sequences=True,name='LSTM1')(input_data_1)
    Flatten1 = Flatten(name="Flatten1")(LSTM1)
    predictions0 = Dense(1, activation='sigmoid',name="predictions0")(Flatten1)
    # CNN-2分支
    cnn_out = Conv1D(filters=16, kernel_size=8, activation='relu',padding='same', 
                     input_shape=(16, 1),name="cnn_out")(input_data_2)
    Flatten2 = Flatten(name="Flatten2")(cnn_out)
    Dense2 = Dense(16, activation='sigmoid',name="Dense2")(Flatten2)
    predictions1 = Dense(1, activation='sigmoid',name="predictions1")(Dense2)
    # 合并向量：
    merged_vector = concatenate([predictions0, predictions1], axis=-1,name="merged_vector")
    Dense3 = Dense(16, activation='sigmoid',name="Dense3")(merged_vector)
    predictions2 = Dense(1, activation='sigmoid',name="predictions2")(Dense3)
    inputs = [input_data_1,input_data_2]
    model = Model(inputs, predictions2)  
    model.compile(optimizer=optimizer, loss='mse', metrics=['accuracy'])
    model.summary()
    x = "CNN1D_LSTM1"
    return model,x

def build_model_CNN_GRU(optimizer):
    # 定义输入
    input_data_1 = Input(shape=(16,1), name='input_data_sm')
    input_data_2 = Input(shape=(16,1), name='input_data_wh_V')
    # CNN-1分支
    GRU1 = GRU(64,input_shape=(16,1),return_sequences=True,name='GRU1')(input_data_1)
    Flatten1 = Flatten(name="Flatten1")(GRU1)
    predictions0 = Dense(1, activation='sigmoid',name="predictions0")(Flatten1)
    # CNN-2分支
    cnn_out = Conv1D(filters=16, kernel_size=8, activation='relu',padding='same', 
                     input_shape=(16, 1),name="cnn_out")(input_data_2)
    Flatten2 = Flatten(name="Flatten2")(cnn_out)
    Dense2 = Dense(16, activation='sigmoid',name="Dense2")(Flatten2)
    predictions1 = Dense(1, activation='sigmoid',name="predictions1")(Dense2)
    # 合并向量：
    merged_vector = concatenate([predictions0, predictions1], axis=-1,name="merged_vector")
    Dense3 = Dense(16, activation='sigmoid',name="Dense3")(merged_vector)
    predictions2 = Dense(1, activation='sigmoid',name="predictions2")(Dense3)
    inputs = [input_data_1,input_data_2]
    model = Model(inputs, predictions2)  
    model.compile(optimizer=optimizer, loss='mse', metrics=['accuracy'])
    model.summary()
    x = "CNN1D_GRU1"
    return model,x

def build_model_CNN_LSTM2(optimizer):
    # 定义输入
    input_data_1 = Input(shape=(16,1), name='input_data_sm')
    input_data_2 = Input(shape=(16,1), name='input_data_wh_V')
    # CNN-1分支
    LSTM1 = LSTM(64,input_shape=(16,1),return_sequences=True,name='LSTM1')(input_data_1)
    LSTM2 = LSTM(64,name='LSTM2')(LSTM1)

    Flatten1 = Flatten(name="Flatten1")(LSTM2)
    predictions0 = Dense(1, activation='sigmoid',name="predictions0")(Flatten1)
    # CNN-2分支
    cnn_out = Conv1D(filters=16, kernel_size=8, activation='relu',padding='same', 
                     input_shape=(16, 1),name="cnn_out")(input_data_2)
    Flatten2 = Flatten(name="Flatten2")(cnn_out)
    Dense2 = Dense(16, activation='sigmoid',name="Dense2")(Flatten2)
    predictions1 = Dense(1, activation='sigmoid',name="predictions1")(Dense2)
    # 合并向量：
    merged_vector = concatenate([predictions0, predictions1], axis=-1,name="merged_vector")
    Dense3 = Dense(16, activation='sigmoid',name="Dense3")(merged_vector)
    predictions2 = Dense(1, activation='sigmoid',name="predictions2")(Dense3)
    inputs = [input_data_1,input_data_2]
    model = Model(inputs, predictions2)  
    model.compile(optimizer=optimizer, loss='mse', metrics=['accuracy'])
    model.summary()
    x = "CNN1D_LSTM2"
    return model,x

def build_model_CNN_GRU2(optimizer):
    # 定义输入
    input_data_1 = Input(shape=(16,1), name='input_data_sm')
    input_data_2 = Input(shape=(16,1), name='input_data_wh_V')
    # CNN-1分支
    GRU1 = GRU(64,input_shape=(16,1),return_sequences=True,name='GRU1')(input_data_1)
    GRU2 = GRU(64,name='GRU2')(GRU1)

    Flatten1 = Flatten(name="Flatten1")(GRU2)
    predictions0 = Dense(1, activation='sigmoid',name="predictions0")(Flatten1)
    # CNN-2分支
    cnn_out = Conv1D(filters=16, kernel_size=8, activation='relu',padding='same', 
                     input_shape=(16, 1),name="cnn_out")(input_data_2)
    Flatten2 = Flatten(name="Flatten2")(cnn_out)
    Dense2 = Dense(16, activation='sigmoid',name="Dense2")(Flatten2)
    predictions1 = Dense(1, activation='sigmoid',name="predictions1")(Dense2)
    # 合并向量：
    merged_vector = concatenate([predictions0, predictions1], axis=-1,name="merged_vector")
    Dense3 = Dense(16, activation='sigmoid',name="Dense3")(merged_vector)
    predictions2 = Dense(1, activation='sigmoid',name="predictions2")(Dense3)
    inputs = [input_data_1,input_data_2]
    model = Model(inputs, predictions2)  
    model.compile(optimizer=optimizer, loss='mse', metrics=['accuracy'])
    model.summary()
    x = "CNN1D_GRU2"
    return model,x

# %%
# keras-tf相关模块
import tensorflow as tf
from keras.models import load_model
from tensorflow.python.keras import backend as K  
from tensorflow.keras.models import * # Sequential, Model
from tensorflow.keras.layers import * # Dense, Dropout, BatchNormalization, LSTM, Conv1D, Flatten, GRU, Input
from tensorflow.keras import optimizers, regularizers
# from keras.layers import *
# 导入ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint,TensorBoard,Callback,ReduceLROnPlateau,EarlyStopping
# keras查看GPU模块
from keras.utils import *  # multi_gpu_model, plot_model
import time




# 单特征训练
def tain(lr=0.001, feature_size=16, hidden_dim=128, num_layers=2, 
         weight_decay=0.0, mode = 'LSTM', EPOCH=1000, seed=0, list_nums=4):
    # Battery_list ： 样本列表
    # Battery      ：【序号，电池容量】
    score_list, result_list = [], []
    # 训练数据准备
    train_x1, train_y1, test_x1, test_y1 = get_train_test(capacity, window_size=feature_size)
    
    # 归一化
    train_x1_, s1 = Fit_transform(train_x1,0,1)  # s1: <class 'sklearn.preprocessing._data.MinMaxScaler'>
    train_y1_, s2 = Fit_transform(train_y1.reshape(-1,1),0,1)
    test_x1_,  s3 = Fit_transform(test_x1,0,1)
    test_y1_,  s4 = Fit_transform(test_y1.reshape(-1,1),0,1)
    Extremum_matrix = [s1,s2,s3,s4]
    # 添加维度，编程网络输入三维
    train_x2, test_x2 = train_x1_.reshape(train_x1_.shape[0],feature_size,1), test_x1_.reshape(test_x1_.shape[0],feature_size,1)
    # shuffle 测试数据（样本后部分）
    train_x, train_y,_ = shuffle_data(train_x2, train_y1_)
    test_x, test_y,_ = shuffle_data(test_x2, test_y1_)
    print(train_x.shape, train_y.shape, test_x.shape, test_y.shape)

    # 模型配置
    optimizer = 'adam'  # optimizers.Adam(lr=0.001,decay=0.004)
#     model,strr = build_model_LSTM(optimizer) 
#     model,strr = build_model_cnn1d(optimizer)  
#     model,strr = build_model_GRU(optimizer)   
#     model,strr = build_model_CNN_LR(optimizer) 
#     model,strr = build_model_CNN_CNN(optimizer)
#     model,strr = build_model_CNN_LSTM(optimizer)
#     model,strr = build_model_CNN_GRU(optimizer)
#     model,strr = build_model_CNN_LSTM2(optimizer)
    model,strr = build_model_CNN_GRU2(optimizer)

    
    
    checkpoint_save_dir='./test1/'
    EarlyStop=EarlyStopping(monitor='loss'  #'val_acc',
                            ,patience=30,verbose=1, mode='auto')
    checkpoint = ModelCheckpoint(os.path.join(checkpoint_save_dir, "model_%s_1.hdf5"%strr),
                                 monitor='loss', verbose=1, save_best_only=True, mode='min')
    callbacks_list = [checkpoint, EarlyStop]

    start_sampling = time.time()
    # hist_sampling = model.fit(X_train,y_train,
    hist_sampling = model.fit([train_x,train_x],train_y,
    #                           validation_split = 0.2, 
                              validation_data=([test_x,test_x], test_y),
                              batch_size=8, epochs=300,
                              callbacks=callbacks_list,#,reduce_lr],
                              shuffle=True,
                              verbose=1)
    end_sampling = time.time()
    print('训练结束！！')
    print('训练时间（分钟）：',(end_sampling-start_sampling)/60)

    score_sampling = model.evaluate([test_x,test_x],
                                     test_y, batch_size=8)
    # score_sampling = model.evaluate(X_test,y_test, batch_size=128)
    print(score_sampling)
    plt.figure(dpi=150)
    plt.plot(hist_sampling.history['loss'], label='loss')
#     plt.plot(hist_sampling.history['acc'], label='acc')
#     plt.plot(hist_sampling.history['val_acc'], label='val_acc')
    plt.plot(hist_sampling.history['val_loss'], label='val_loss')
    plt.legend()
    plt.savefig('NASA-27-%s-losscurve'%strr)
    plt.show()
    return model, train_x, train_y, test_x, test_y, train_x1, train_y1, test_x1, test_y1, Extremum_matrix, strr

# 0.004 0.018
        
model, train_x, train_y, test_x, test_y, train_x1, train_y1, test_x1, test_y1, Extremum_matrix, strr = tain()
tf.keras.utils.plot_model(model,to_file='%s.png'%strr, show_shapes=True,show_layer_names=True)   

#         setup_seed(seed)
#         model = Net(input_size=feature_size, hidden_dim=hidden_dim, num_layers=num_layers, mode=mode)
#         model = model.to(device)
# Out:
# (1427, 16, 1) (1427, 1) (497, 16, 1) (497, 1)
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_data_sm (InputLayer)      [(None, 16, 1)]      0
# __________________________________________________________________________________________________
# input_data_wh_V (InputLayer)    [(None, 16, 1)]      0
# __________________________________________________________________________________________________
# GRU1 (GRU)                      (None, 16, 64)       12672       input_data_sm[0][0]
# __________________________________________________________________________________________________
# cnn_out (Conv1D)                (None, 16, 16)       144         input_data_wh_V[0][0]
# __________________________________________________________________________________________________
# GRU2 (GRU)                      (None, 64)           24768       GRU1[0][0]
# __________________________________________________________________________________________________
# Flatten2 (Flatten)              (None, 256)          0           cnn_out[0][0]
# __________________________________________________________________________________________________
# Flatten1 (Flatten)              (None, 64)           0           GRU2[0][0]
# __________________________________________________________________________________________________
# Dense2 (Dense)                  (None, 16)           4112        Flatten2[0][0]
# __________________________________________________________________________________________________
# predictions0 (Dense)            (None, 1)            65          Flatten1[0][0]
# __________________________________________________________________________________________________
# predictions1 (Dense)            (None, 1)            17          Dense2[0][0]
# __________________________________________________________________________________________________
# merged_vector (Concatenate)     (None, 2)            0           predictions0[0][0]
#                                                                  predictions1[0][0]
# __________________________________________________________________________________________________
# Dense3 (Dense)                  (None, 16)           48          merged_vector[0][0]
# __________________________________________________________________________________________________
# predictions2 (Dense)            (None, 1)            17          Dense3[0][0]
# ==================================================================================================
# Total params: 41,843
# Trainable params: 41,843
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 1427 samples, validate on 497 samples
# Epoch 1/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0438 - acc: 7.1429e-04
# Epoch 00001: loss improved from inf to 0.04331, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 4s 3ms/sample - loss: 0.0433 - acc: 7.0077e-04 - val_loss: 0.0848 - val_acc: 0.0020
# Epoch 2/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0337 - acc: 0.0014
# Epoch 00002: loss improved from 0.04331 to 0.03356, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0336 - acc: 0.0014 - val_loss: 0.0661 - val_acc: 0.0040
# Epoch 3/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0229 - acc: 0.0014
# Epoch 00003: loss improved from 0.03356 to 0.02282, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0228 - acc: 0.0014 - val_loss: 0.0572 - val_acc: 0.0060
# Epoch 4/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0148 - acc: 7.1429e-04
# Epoch 00004: loss improved from 0.02282 to 0.01479, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0148 - acc: 0.0014 - val_loss: 0.0526 - val_acc: 0.0060
# Epoch 5/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0099 - acc: 0.0014
# Epoch 00005: loss improved from 0.01479 to 0.00997, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0100 - acc: 0.0014 - val_loss: 0.0442 - val_acc: 0.0060
# Epoch 6/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0074 - acc: 0.0014
# Epoch 00006: loss improved from 0.00997 to 0.00750, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0075 - acc: 0.0014 - val_loss: 0.0382 - val_acc: 0.0060
# Epoch 7/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0060 - acc: 0.0014
# Epoch 00007: loss improved from 0.00750 to 0.00592, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0059 - acc: 0.0014 - val_loss: 0.0353 - val_acc: 0.0060
# Epoch 8/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0051 - acc: 0.0014
# Epoch 00008: loss improved from 0.00592 to 0.00503, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0050 - acc: 0.0014 - val_loss: 0.0335 - val_acc: 0.0060
# Epoch 9/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0042 - acc: 0.0014
# Epoch 00009: loss improved from 0.00503 to 0.00443, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0044 - acc: 0.0014 - val_loss: 0.0326 - val_acc: 0.0060
# Epoch 10/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0043 - acc: 0.0014
# Epoch 00010: loss improved from 0.00443 to 0.00421, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0042 - acc: 0.0014 - val_loss: 0.0312 - val_acc: 0.0060
# Epoch 11/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0040 - acc: 0.0014
# Epoch 00011: loss improved from 0.00421 to 0.00395, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0039 - acc: 0.0014 - val_loss: 0.0305 - val_acc: 0.0060
# Epoch 12/300
# 1384/1427 [============================>.] - ETA: 0s - loss: 0.0036 - acc: 0.0014
# Epoch 00012: loss improved from 0.00395 to 0.00374, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0037 - acc: 0.0014 - val_loss: 0.0305 - val_acc: 0.0060
# Epoch 13/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0038 - acc: 0.0014
# Epoch 00013: loss improved from 0.00374 to 0.00372, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0037 - acc: 0.0014 - val_loss: 0.0290 - val_acc: 0.0060
# Epoch 14/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0034 - acc: 0.0014
# Epoch 00014: loss improved from 0.00372 to 0.00359, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0036 - acc: 0.0014 - val_loss: 0.0291 - val_acc: 0.0060
# Epoch 15/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 7.1023e-04
# Epoch 00015: loss improved from 0.00359 to 0.00350, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0035 - acc: 0.0014 - val_loss: 0.0288 - val_acc: 0.0060
# Epoch 16/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0036 - acc: 0.0021
# Epoch 00016: loss did not improve from 0.00350
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0036 - acc: 0.0021 - val_loss: 0.0281 - val_acc: 0.0060
# Epoch 17/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0035 - acc: 0.0022
# Epoch 00017: loss improved from 0.00350 to 0.00343, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0034 - acc: 0.0021 - val_loss: 0.0277 - val_acc: 0.0060
# Epoch 18/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0035 - acc: 0.0014
# Epoch 00018: loss improved from 0.00343 to 0.00342, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0034 - acc: 0.0014 - val_loss: 0.0271 - val_acc: 0.0060
# Epoch 19/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0034 - acc: 0.0014
# Epoch 00019: loss improved from 0.00342 to 0.00340, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0034 - acc: 0.0014 - val_loss: 0.0265 - val_acc: 0.0060
# Epoch 20/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0034 - acc: 0.0014
# Epoch 00020: loss improved from 0.00340 to 0.00338, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0034 - acc: 0.0014 - val_loss: 0.0267 - val_acc: 0.0060
# Epoch 21/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0034 - acc: 0.0022
# Epoch 00021: loss improved from 0.00338 to 0.00332, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0033 - acc: 0.0021 - val_loss: 0.0265 - val_acc: 0.0060
# Epoch 22/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 0.0014
# Epoch 00022: loss did not improve from 0.00332
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0034 - acc: 0.0014 - val_loss: 0.0254 - val_acc: 0.0060
# Epoch 23/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0034 - acc: 7.1429e-04
# Epoch 00023: loss did not improve from 0.00332
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0034 - acc: 0.0014 - val_loss: 0.0253 - val_acc: 0.0060
# Epoch 24/300
# 1416/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00024: loss improved from 0.00332 to 0.00331, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0033 - acc: 0.0014 - val_loss: 0.0254 - val_acc: 0.0060
# Epoch 25/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0034 - acc: 0.0014
# Epoch 00025: loss did not improve from 0.00331
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0033 - acc: 0.0014 - val_loss: 0.0250 - val_acc: 0.0060
# Epoch 26/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0033 - acc: 0.0014
# Epoch 00026: loss improved from 0.00331 to 0.00330, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0033 - acc: 0.0014 - val_loss: 0.0251 - val_acc: 0.0060
# Epoch 27/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0034 - acc: 0.0014
# Epoch 00027: loss did not improve from 0.00330
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0034 - acc: 0.0014 - val_loss: 0.0248 - val_acc: 0.0060
# Epoch 28/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0033 - acc: 0.0014
# Epoch 00028: loss improved from 0.00330 to 0.00327, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0033 - acc: 0.0014 - val_loss: 0.0250 - val_acc: 0.0060
# Epoch 29/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 0.0014
# Epoch 00029: loss improved from 0.00327 to 0.00324, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0032 - acc: 0.0014 - val_loss: 0.0251 - val_acc: 0.0060
# Epoch 30/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 0.0014
# Epoch 00030: loss improved from 0.00324 to 0.00313, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0241 - val_acc: 0.0060
# Epoch 31/300
# 1416/1427 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 0.0014
# Epoch 00031: loss did not improve from 0.00313
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0032 - acc: 0.0014 - val_loss: 0.0236 - val_acc: 0.0060
# Epoch 32/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00032: loss improved from 0.00313 to 0.00311, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0234 - val_acc: 0.0060
# Epoch 33/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 0.0014
# Epoch 00033: loss did not improve from 0.00311
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0032 - acc: 0.0014 - val_loss: 0.0245 - val_acc: 0.0060
# Epoch 34/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 7.1023e-04
# Epoch 00034: loss did not improve from 0.00311
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0032 - acc: 0.0014 - val_loss: 0.0235 - val_acc: 0.0060
# Epoch 35/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 0.0014
# Epoch 00035: loss did not improve from 0.00311
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0032 - acc: 0.0014 - val_loss: 0.0232 - val_acc: 0.0060
# Epoch 36/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 0.0014
# Epoch 00036: loss improved from 0.00311 to 0.00311, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0233 - val_acc: 0.0060
# Epoch 37/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0033 - acc: 0.0014
# Epoch 00037: loss did not improve from 0.00311
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0032 - acc: 0.0014 - val_loss: 0.0226 - val_acc: 0.0060
# Epoch 38/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 0.0014
# Epoch 00038: loss did not improve from 0.00311
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0231 - val_acc: 0.0060
# Epoch 39/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00039: loss improved from 0.00311 to 0.00308, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0225 - val_acc: 0.0060
# Epoch 40/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00040: loss did not improve from 0.00308
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0224 - val_acc: 0.0060
# Epoch 41/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00041: loss did not improve from 0.00308
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0221 - val_acc: 0.0060
# Epoch 42/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00042: loss did not improve from 0.00308
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0226 - val_acc: 0.0060
# Epoch 43/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00043: loss did not improve from 0.00308
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0220 - val_acc: 0.0060
# Epoch 44/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00044: loss improved from 0.00308 to 0.00305, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0221 - val_acc: 0.0060
# Epoch 45/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00045: loss did not improve from 0.00305
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0222 - val_acc: 0.0060
# Epoch 46/300
# 1384/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00046: loss did not improve from 0.00305
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0221 - val_acc: 0.0060
# Epoch 47/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 7.1429e-04
# Epoch 00047: loss did not improve from 0.00305
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0216 - val_acc: 0.0060
# Epoch 48/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 0.0014
# Epoch 00048: loss did not improve from 0.00305
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0253 - val_acc: 0.0060
# Epoch 49/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0033 - acc: 0.0014
# Epoch 00049: loss did not improve from 0.00305
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0032 - acc: 0.0014 - val_loss: 0.0222 - val_acc: 0.0060
# Epoch 50/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0027 - acc: 0.0014
# Epoch 00050: loss did not improve from 0.00305
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0222 - val_acc: 0.0060
# Epoch 51/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 0.0014
# Epoch 00051: loss did not improve from 0.00305
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0220 - val_acc: 0.0060
# Epoch 52/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00052: loss did not improve from 0.00305
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0221 - val_acc: 0.0060
# Epoch 53/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 7.1023e-04
# Epoch 00053: loss did not improve from 0.00305
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0218 - val_acc: 0.0060
# Epoch 54/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00054: loss did not improve from 0.00305
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0212 - val_acc: 0.0060
# Epoch 55/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00055: loss improved from 0.00305 to 0.00303, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0218 - val_acc: 0.0060
# Epoch 56/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00056: loss did not improve from 0.00303
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0217 - val_acc: 0.0060
# Epoch 57/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00057: loss did not improve from 0.00303
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0216 - val_acc: 0.0060
# Epoch 58/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00058: loss did not improve from 0.00303
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0217 - val_acc: 0.0060
# Epoch 59/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0028 - acc: 7.1839e-04
# Epoch 00059: loss did not improve from 0.00303
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0213 - val_acc: 0.0060
# Epoch 60/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 0.0014
# Epoch 00060: loss did not improve from 0.00303
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0032 - acc: 0.0014 - val_loss: 0.0213 - val_acc: 0.0060
# Epoch 61/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00061: loss did not improve from 0.00303
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0211 - val_acc: 0.0060
# Epoch 62/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 0.0014
# Epoch 00062: loss did not improve from 0.00303
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0211 - val_acc: 0.0060
# Epoch 63/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 7.1429e-04
# Epoch 00063: loss did not improve from 0.00303
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0214 - val_acc: 0.0060
# Epoch 64/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00064: loss did not improve from 0.00303
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0212 - val_acc: 0.0060
# Epoch 65/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00065: loss did not improve from 0.00303
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0213 - val_acc: 0.0060
# Epoch 66/300
# 1416/1427 [============================>.] - ETA: 0s - loss: 0.0028 - acc: 0.0014
# Epoch 00066: loss did not improve from 0.00303
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0217 - val_acc: 0.0060
# Epoch 67/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00067: loss did not improve from 0.00303
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0211 - val_acc: 0.0060
# Epoch 68/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00068: loss did not improve from 0.00303
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0216 - val_acc: 0.0060
# Epoch 69/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00069: loss did not improve from 0.00303
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0212 - val_acc: 0.0060
# Epoch 70/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00070: loss did not improve from 0.00303
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0212 - val_acc: 0.0060
# Epoch 71/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00071: loss did not improve from 0.00303
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0218 - val_acc: 0.0060
# Epoch 72/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00072: loss did not improve from 0.00303
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0215 - val_acc: 0.0060
# Epoch 73/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00073: loss did not improve from 0.00303
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0220 - val_acc: 0.0060
# Epoch 74/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00074: loss did not improve from 0.00303
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0215 - val_acc: 0.0060
# Epoch 75/300
# 1416/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00075: loss improved from 0.00303 to 0.00302, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0214 - val_acc: 0.0060
# Epoch 76/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00076: loss did not improve from 0.00302
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0214 - val_acc: 0.0060
# Epoch 77/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00077: loss did not improve from 0.00302
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0218 - val_acc: 0.0060
# Epoch 78/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00078: loss did not improve from 0.00302
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0215 - val_acc: 0.0060
# Epoch 79/300
# 1384/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00079: loss did not improve from 0.00302
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0211 - val_acc: 0.0060
# Epoch 80/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00080: loss did not improve from 0.00302
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0214 - val_acc: 0.0060
# Epoch 81/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00081: loss did not improve from 0.00302
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0213 - val_acc: 0.0060
# Epoch 82/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 0.0014
# Epoch 00082: loss did not improve from 0.00302
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0215 - val_acc: 0.0060
# Epoch 83/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 0.0014
# Epoch 00083: loss did not improve from 0.00302
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0210 - val_acc: 0.0060
# Epoch 84/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00084: loss did not improve from 0.00302
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0214 - val_acc: 0.0060
# Epoch 85/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00085: loss did not improve from 0.00302
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0217 - val_acc: 0.0060
# Epoch 86/300
# 1384/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00086: loss did not improve from 0.00302
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0213 - val_acc: 0.0060
# Epoch 87/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00087: loss did not improve from 0.00302
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0215 - val_acc: 0.0060
# Epoch 88/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00088: loss did not improve from 0.00302
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0216 - val_acc: 0.0060
# Epoch 89/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00089: loss improved from 0.00302 to 0.00301, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0215 - val_acc: 0.0060
# Epoch 90/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00090: loss did not improve from 0.00301
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0216 - val_acc: 0.0060
# Epoch 91/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00091: loss did not improve from 0.00301
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0215 - val_acc: 0.0060
# Epoch 92/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00092: loss improved from 0.00301 to 0.00301, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0213 - val_acc: 0.0060
# Epoch 93/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00093: loss improved from 0.00301 to 0.00301, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0223 - val_acc: 0.0060
# Epoch 94/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00094: loss did not improve from 0.00301
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0213 - val_acc: 0.0060
# Epoch 95/300
# 1416/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00095: loss did not improve from 0.00301
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0211 - val_acc: 0.0060
# Epoch 96/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00096: loss did not improve from 0.00301
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0208 - val_acc: 0.0060
# Epoch 97/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00097: loss did not improve from 0.00301
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0211 - val_acc: 0.0060
# Epoch 98/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00098: loss did not improve from 0.00301
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0215 - val_acc: 0.0060
# Epoch 99/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00099: loss did not improve from 0.00301
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0219 - val_acc: 0.0060
# Epoch 100/300
# 1384/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 7.2254e-04
# Epoch 00100: loss did not improve from 0.00301
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0224 - val_acc: 0.0060
# Epoch 101/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00101: loss did not improve from 0.00301
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0219 - val_acc: 0.0060
# Epoch 102/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0028 - acc: 0.0014
# Epoch 00102: loss did not improve from 0.00301
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0222 - val_acc: 0.0060
# Epoch 103/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 0.0014
# Epoch 00103: loss did not improve from 0.00301
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0031 - acc: 0.0014 - val_loss: 0.0221 - val_acc: 0.0060
# Epoch 104/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00104: loss improved from 0.00301 to 0.00300, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0214 - val_acc: 0.0060
# Epoch 105/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00105: loss did not improve from 0.00300
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0220 - val_acc: 0.0060
# Epoch 106/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0028 - acc: 0.0014
# Epoch 00106: loss improved from 0.00300 to 0.00300, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0219 - val_acc: 0.0060
# Epoch 107/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00107: loss did not improve from 0.00300
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0214 - val_acc: 0.0060
# Epoch 108/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00108: loss did not improve from 0.00300
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0217 - val_acc: 0.0060
# Epoch 109/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00109: loss did not improve from 0.00300
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0218 - val_acc: 0.0060
# Epoch 110/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00110: loss did not improve from 0.00300
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0216 - val_acc: 0.0060
# Epoch 111/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00111: loss did not improve from 0.00300
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0216 - val_acc: 0.0060
# Epoch 112/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0028 - acc: 0.0014
# Epoch 00112: loss did not improve from 0.00300
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0223 - val_acc: 0.0060
# Epoch 113/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00113: loss did not improve from 0.00300
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0217 - val_acc: 0.0060
# Epoch 114/300
# 1416/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00114: loss improved from 0.00300 to 0.00298, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0214 - val_acc: 0.0060
# Epoch 115/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00115: loss improved from 0.00298 to 0.00297, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0216 - val_acc: 0.0060
# Epoch 116/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00116: loss did not improve from 0.00297
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0217 - val_acc: 0.0060
# Epoch 117/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00117: loss did not improve from 0.00297
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0220 - val_acc: 0.0060
# Epoch 118/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00118: loss did not improve from 0.00297
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0214 - val_acc: 0.0060
# Epoch 119/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00119: loss did not improve from 0.00297
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0218 - val_acc: 0.0060
# Epoch 120/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00120: loss did not improve from 0.00297
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0217 - val_acc: 0.0060
# Epoch 121/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00121: loss did not improve from 0.00297
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0221 - val_acc: 0.0060
# Epoch 122/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00122: loss did not improve from 0.00297
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0213 - val_acc: 0.0060
# Epoch 123/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0028 - acc: 0.0014
# Epoch 00123: loss improved from 0.00297 to 0.00295, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0029 - acc: 0.0014 - val_loss: 0.0215 - val_acc: 0.0060
# Epoch 124/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00124: loss did not improve from 0.00295
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0223 - val_acc: 0.0060
# Epoch 125/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00125: loss did not improve from 0.00295
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0222 - val_acc: 0.0060
# Epoch 126/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00126: loss did not improve from 0.00295
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0222 - val_acc: 0.0060
# Epoch 127/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00127: loss did not improve from 0.00295
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0222 - val_acc: 0.0060
# Epoch 128/300
# 1416/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00128: loss did not improve from 0.00295
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0218 - val_acc: 0.0060
# Epoch 129/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00129: loss did not improve from 0.00295
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0237 - val_acc: 0.0060
# Epoch 130/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00130: loss did not improve from 0.00295
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0222 - val_acc: 0.0060
# Epoch 131/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00131: loss did not improve from 0.00295
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0218 - val_acc: 0.0060
# Epoch 132/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0028 - acc: 0.0014
# Epoch 00132: loss did not improve from 0.00295
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0221 - val_acc: 0.0060
# Epoch 133/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00133: loss did not improve from 0.00295
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0229 - val_acc: 0.0060
# Epoch 134/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00134: loss did not improve from 0.00295
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0229 - val_acc: 0.0060
# Epoch 135/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00135: loss did not improve from 0.00295
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0220 - val_acc: 0.0060
# Epoch 136/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00136: loss improved from 0.00295 to 0.00287, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0029 - acc: 0.0014 - val_loss: 0.0227 - val_acc: 0.0060
# Epoch 137/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00137: loss did not improve from 0.00287
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0029 - acc: 0.0014 - val_loss: 0.0225 - val_acc: 0.0060
# Epoch 138/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00138: loss did not improve from 0.00287
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0029 - acc: 0.0014 - val_loss: 0.0233 - val_acc: 0.0060
# Epoch 139/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0028 - acc: 0.0014
# Epoch 00139: loss did not improve from 0.00287
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0029 - acc: 0.0014 - val_loss: 0.0237 - val_acc: 0.0060
# Epoch 140/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00140: loss did not improve from 0.00287
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0029 - acc: 0.0014 - val_loss: 0.0227 - val_acc: 0.0060
# Epoch 141/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00141: loss did not improve from 0.00287
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0029 - acc: 0.0014 - val_loss: 0.0220 - val_acc: 0.0060
# Epoch 142/300
# 1416/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0014
# Epoch 00142: loss did not improve from 0.00287
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0233 - val_acc: 0.0060
# Epoch 143/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00143: loss did not improve from 0.00287
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0029 - acc: 0.0014 - val_loss: 0.0220 - val_acc: 0.0060
# Epoch 144/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0027 - acc: 0.0014
# Epoch 00144: loss did not improve from 0.00287
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0029 - acc: 0.0021 - val_loss: 0.0232 - val_acc: 0.0060
# Epoch 145/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00145: loss did not improve from 0.00287
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0014 - val_loss: 0.0232 - val_acc: 0.0060
# Epoch 146/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0014
# Epoch 00146: loss did not improve from 0.00287
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0029 - acc: 0.0014 - val_loss: 0.0241 - val_acc: 0.0060
# Epoch 147/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0027 - acc: 0.0022
# Epoch 00147: loss improved from 0.00287 to 0.00286, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0029 - acc: 0.0021 - val_loss: 0.0236 - val_acc: 0.0060
# Epoch 148/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00148: loss did not improve from 0.00286
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0029 - acc: 0.0014 - val_loss: 0.0242 - val_acc: 0.0060
# Epoch 149/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0021
# Epoch 00149: loss did not improve from 0.00286
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0029 - acc: 0.0021 - val_loss: 0.0227 - val_acc: 0.0060
# Epoch 150/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0021
# Epoch 00150: loss improved from 0.00286 to 0.00283, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0028 - acc: 0.0021 - val_loss: 0.0233 - val_acc: 0.0060
# Epoch 151/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00151: loss did not improve from 0.00283
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0029 - acc: 0.0014 - val_loss: 0.0226 - val_acc: 0.0060
# Epoch 152/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0022
# Epoch 00152: loss did not improve from 0.00283
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0029 - acc: 0.0021 - val_loss: 0.0226 - val_acc: 0.0060
# Epoch 153/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0027 - acc: 0.0022
# Epoch 00153: loss did not improve from 0.00283
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0028 - acc: 0.0021 - val_loss: 0.0227 - val_acc: 0.0060
# Epoch 154/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0029
# Epoch 00154: loss did not improve from 0.00283
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0029 - acc: 0.0028 - val_loss: 0.0232 - val_acc: 0.0060
# Epoch 155/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0022
# Epoch 00155: loss did not improve from 0.00283
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0029 - acc: 0.0021 - val_loss: 0.0222 - val_acc: 0.0060
# Epoch 156/300
# 1416/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0021
# Epoch 00156: loss did not improve from 0.00283
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0029 - acc: 0.0021 - val_loss: 0.0271 - val_acc: 0.0060
# Epoch 157/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0028
# Epoch 00157: loss did not improve from 0.00283
# 1427/1427 [==============================] - 2s 2ms/sample - loss: 0.0029 - acc: 0.0028 - val_loss: 0.0232 - val_acc: 0.0060
# Epoch 158/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0021
# Epoch 00158: loss did not improve from 0.00283
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0029 - acc: 0.0021 - val_loss: 0.0265 - val_acc: 0.0060
# Epoch 159/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0022
# Epoch 00159: loss did not improve from 0.00283
# ...
# Epoch 00243: loss did not improve from 0.00246
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0028 - acc: 0.0028 - val_loss: 0.0230 - val_acc: 0.0060
# Epoch 244/300
# 1384/1427 [============================>.] - ETA: 0s - loss: 0.0028 - acc: 0.0029
# Epoch 00244: loss did not improve from 0.00246
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0028 - acc: 0.0028 - val_loss: 0.0284 - val_acc: 0.0060
# Epoch 245/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0014
# Epoch 00245: loss did not improve from 0.00246
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0028 - acc: 0.0014 - val_loss: 0.0254 - val_acc: 0.0060
# Epoch 246/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0027 - acc: 0.0035
# Epoch 00246: loss did not improve from 0.00246
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0027 - acc: 0.0035 - val_loss: 0.0240 - val_acc: 0.0060
# Epoch 247/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0026 - acc: 0.0028
# Epoch 00247: loss did not improve from 0.00246
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0026 - acc: 0.0028 - val_loss: 0.0259 - val_acc: 0.0060
# Epoch 248/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0027 - acc: 0.0029
# Epoch 00248: loss did not improve from 0.00246
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0026 - acc: 0.0028 - val_loss: 0.0248 - val_acc: 0.0060
# Epoch 249/300
# 1376/1427 [===========================>..] - ETA: 0s - loss: 0.0028 - acc: 0.0036
# Epoch 00249: loss did not improve from 0.00246
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0027 - acc: 0.0035 - val_loss: 0.0268 - val_acc: 0.0060
# Epoch 250/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0023 - acc: 0.0036
# Epoch 00250: loss did not improve from 0.00246
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0025 - acc: 0.0035 - val_loss: 0.0282 - val_acc: 0.0060
# Epoch 251/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0024 - acc: 0.0036
# Epoch 00251: loss improved from 0.00246 to 0.00242, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0024 - acc: 0.0035 - val_loss: 0.0276 - val_acc: 0.0060
# Epoch 252/300
# 1384/1427 [============================>.] - ETA: 0s - loss: 0.0026 - acc: 0.0029
# Epoch 00252: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0026 - acc: 0.0028 - val_loss: 0.0260 - val_acc: 0.0060
# Epoch 253/300
# 1384/1427 [============================>.] - ETA: 0s - loss: 0.0028 - acc: 0.0022
# Epoch 00253: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0028 - acc: 0.0021 - val_loss: 0.0264 - val_acc: 0.0060
# Epoch 254/300
# 1416/1427 [============================>.] - ETA: 0s - loss: 0.0026 - acc: 0.0035
# Epoch 00254: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0026 - acc: 0.0035 - val_loss: 0.0282 - val_acc: 0.0060
# Epoch 255/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0026 - acc: 0.0036
# Epoch 00255: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0026 - acc: 0.0035 - val_loss: 0.0266 - val_acc: 0.0060
# Epoch 256/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0026 - acc: 0.0036
# Epoch 00256: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0025 - acc: 0.0035 - val_loss: 0.0288 - val_acc: 0.0060
# Epoch 257/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0026 - acc: 0.0036
# Epoch 00257: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0025 - acc: 0.0035 - val_loss: 0.0299 - val_acc: 0.0060
# Epoch 258/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0027 - acc: 0.0036
# Epoch 00258: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0026 - acc: 0.0035 - val_loss: 0.0342 - val_acc: 0.0060
# Epoch 259/300
# 1384/1427 [============================>.] - ETA: 0s - loss: 0.0027 - acc: 0.0036
# Epoch 00259: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0027 - acc: 0.0035 - val_loss: 0.0245 - val_acc: 0.0060
# Epoch 260/300
# 1416/1427 [============================>.] - ETA: 0s - loss: 0.0025 - acc: 0.0035
# Epoch 00260: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0025 - acc: 0.0035 - val_loss: 0.0249 - val_acc: 0.0060
# Epoch 261/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0026 - acc: 0.0036
# Epoch 00261: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0026 - acc: 0.0035 - val_loss: 0.0258 - val_acc: 0.0060
# Epoch 262/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0027 - acc: 0.0029
# Epoch 00262: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0027 - acc: 0.0028 - val_loss: 0.0240 - val_acc: 0.0060
# Epoch 263/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0026 - acc: 0.0036
# Epoch 00263: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0025 - acc: 0.0035 - val_loss: 0.0257 - val_acc: 0.0060
# Epoch 264/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0025 - acc: 0.0036
# Epoch 00264: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0025 - acc: 0.0035 - val_loss: 0.0270 - val_acc: 0.0060
# Epoch 265/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0023 - acc: 0.0036
# Epoch 00265: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0025 - acc: 0.0035 - val_loss: 0.0248 - val_acc: 0.0060
# Epoch 266/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0025 - acc: 0.0036
# Epoch 00266: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0025 - acc: 0.0035 - val_loss: 0.0263 - val_acc: 0.0060
# Epoch 267/300
# 1416/1427 [============================>.] - ETA: 0s - loss: 0.0026 - acc: 0.0035
# Epoch 00267: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0026 - acc: 0.0035 - val_loss: 0.0262 - val_acc: 0.0060
# Epoch 268/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.0021
# Epoch 00268: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0021 - val_loss: 0.0197 - val_acc: 0.0060
# Epoch 269/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0027 - acc: 0.0022
# Epoch 00269: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0028 - acc: 0.0021 - val_loss: 0.0274 - val_acc: 0.0060
# Epoch 270/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0026 - acc: 0.0036
# Epoch 00270: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0025 - acc: 0.0035 - val_loss: 0.0274 - val_acc: 0.0060
# Epoch 271/300
# 1384/1427 [============================>.] - ETA: 0s - loss: 0.0025 - acc: 0.0029
# Epoch 00271: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0025 - acc: 0.0035 - val_loss: 0.0275 - val_acc: 0.0060
# Epoch 272/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0023 - acc: 0.0036
# Epoch 00272: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0025 - acc: 0.0035 - val_loss: 0.0261 - val_acc: 0.0060
# Epoch 273/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0025 - acc: 0.0035
# Epoch 00273: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0024 - acc: 0.0035 - val_loss: 0.0263 - val_acc: 0.0060
# Epoch 274/300
# 1376/1427 [===========================>..] - ETA: 0s - loss: 0.0026 - acc: 0.0036
# Epoch 00274: loss did not improve from 0.00242
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0025 - acc: 0.0035 - val_loss: 0.0250 - val_acc: 0.0060
# Epoch 275/300
# 1424/1427 [============================>.] - ETA: 0s - loss: 0.0024 - acc: 0.0035
# Epoch 00275: loss improved from 0.00242 to 0.00240, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0024 - acc: 0.0035 - val_loss: 0.0251 - val_acc: 0.0060
# Epoch 276/300
# 1400/1427 [============================>.] - ETA: 0s - loss: 0.0026 - acc: 0.0029
# Epoch 00276: loss did not improve from 0.00240
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0025 - acc: 0.0028 - val_loss: 0.0267 - val_acc: 0.0060
# Epoch 277/300
# 1376/1427 [===========================>..] - ETA: 0s - loss: 0.0025 - acc: 0.0036
# Epoch 00277: loss improved from 0.00240 to 0.00239, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0024 - acc: 0.0035 - val_loss: 0.0244 - val_acc: 0.0060
# Epoch 278/300
# 1416/1427 [============================>.] - ETA: 0s - loss: 0.0024 - acc: 0.0035
# Epoch 00278: loss improved from 0.00239 to 0.00236, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0024 - acc: 0.0035 - val_loss: 0.0249 - val_acc: 0.0060
# Epoch 279/300
# 1416/1427 [============================>.] - ETA: 0s - loss: 0.0025 - acc: 0.0035
# Epoch 00279: loss did not improve from 0.00236
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0025 - acc: 0.0035 - val_loss: 0.0255 - val_acc: 0.0060
# Epoch 280/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0025 - acc: 0.0036
# Epoch 00280: loss did not improve from 0.00236
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0024 - acc: 0.0035 - val_loss: 0.0236 - val_acc: 0.0060
# Epoch 281/300
# 1384/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0022
# Epoch 00281: loss did not improve from 0.00236
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0028 - acc: 0.0021 - val_loss: 0.0189 - val_acc: 0.0060
# Epoch 282/300
# 1384/1427 [============================>.] - ETA: 0s - loss: 0.0028 - acc: 0.0014
# Epoch 00282: loss did not improve from 0.00236
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0029 - acc: 0.0014 - val_loss: 0.0208 - val_acc: 0.0060
# Epoch 283/300
# 1416/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0028
# Epoch 00283: loss did not improve from 0.00236
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0028 - acc: 0.0028 - val_loss: 0.0208 - val_acc: 0.0060
# Epoch 284/300
# 1416/1427 [============================>.] - ETA: 0s - loss: 0.0028 - acc: 0.0028
# Epoch 00284: loss did not improve from 0.00236
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0027 - acc: 0.0028 - val_loss: 0.0254 - val_acc: 0.0060
# Epoch 285/300
# 1384/1427 [============================>.] - ETA: 0s - loss: 0.0027 - acc: 0.0029
# Epoch 00285: loss did not improve from 0.00236
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0027 - acc: 0.0028 - val_loss: 0.0237 - val_acc: 0.0060
# Epoch 286/300
# 1416/1427 [============================>.] - ETA: 0s - loss: 0.0025 - acc: 0.0035
# Epoch 00286: loss did not improve from 0.00236
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0025 - acc: 0.0035 - val_loss: 0.0238 - val_acc: 0.0060
# Epoch 287/300
# 1416/1427 [============================>.] - ETA: 0s - loss: 0.0024 - acc: 0.0028
# Epoch 00287: loss did not improve from 0.00236
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0025 - acc: 0.0035 - val_loss: 0.0263 - val_acc: 0.0060
# Epoch 288/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0027 - acc: 0.0036
# Epoch 00288: loss did not improve from 0.00236
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0026 - acc: 0.0035 - val_loss: 0.0248 - val_acc: 0.0060
# Epoch 289/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0028 - acc: 0.0029
# Epoch 00289: loss did not improve from 0.00236
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0027 - acc: 0.0028 - val_loss: 0.0220 - val_acc: 0.0060
# Epoch 290/300
# 1416/1427 [============================>.] - ETA: 0s - loss: 0.0026 - acc: 0.0035
# Epoch 00290: loss did not improve from 0.00236
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0026 - acc: 0.0035 - val_loss: 0.0259 - val_acc: 0.0060
# Epoch 291/300
# 1376/1427 [===========================>..] - ETA: 0s - loss: 0.0027 - acc: 0.0036
# Epoch 00291: loss did not improve from 0.00236
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0027 - acc: 0.0035 - val_loss: 0.0263 - val_acc: 0.0060
# Epoch 292/300
# 1384/1427 [============================>.] - ETA: 0s - loss: 0.0023 - acc: 0.0036
# Epoch 00292: loss did not improve from 0.00236
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0024 - acc: 0.0035 - val_loss: 0.0247 - val_acc: 0.0060
# Epoch 293/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0025 - acc: 0.0036
# Epoch 00293: loss did not improve from 0.00236
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0024 - acc: 0.0035 - val_loss: 0.0264 - val_acc: 0.0060
# Epoch 294/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0024 - acc: 0.0036
# Epoch 00294: loss improved from 0.00236 to 0.00234, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0023 - acc: 0.0035 - val_loss: 0.0231 - val_acc: 0.0060
# Epoch 295/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0024 - acc: 0.0036
# Epoch 00295: loss did not improve from 0.00234
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0023 - acc: 0.0035 - val_loss: 0.0242 - val_acc: 0.0060
# Epoch 296/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0023 - acc: 0.0028
# Epoch 00296: loss improved from 0.00234 to 0.00231, saving model to ./test1/model_CNN1D_GRU2_1.hdf5
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0023 - acc: 0.0035 - val_loss: 0.0265 - val_acc: 0.0060
# Epoch 297/300
# 1376/1427 [===========================>..] - ETA: 0s - loss: 0.0024 - acc: 0.0036
# Epoch 00297: loss did not improve from 0.00231
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0023 - acc: 0.0035 - val_loss: 0.0250 - val_acc: 0.0060
# Epoch 298/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0025 - acc: 0.0036
# Epoch 00298: loss did not improve from 0.00231
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0025 - acc: 0.0035 - val_loss: 0.0216 - val_acc: 0.0060
# Epoch 299/300
# 1408/1427 [============================>.] - ETA: 0s - loss: 0.0031 - acc: 0.0021
# Epoch 00299: loss did not improve from 0.00231
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0030 - acc: 0.0021 - val_loss: 0.0195 - val_acc: 0.0060
# Epoch 300/300
# 1392/1427 [============================>.] - ETA: 0s - loss: 0.0029 - acc: 0.0029
# Epoch 00300: loss did not improve from 0.00231
# 1427/1427 [==============================] - 2s 1ms/sample - loss: 0.0028 - acc: 0.0028 - val_loss: 0.0209 - val_acc: 0.0040
# 训练结束！！
# 训练时间（分钟）： 9.805196126302084
# 497/497 [==============================] - 0s 268us/sample - loss: 0.0209 - acc: 0.0040
# [0.020910718576875806, 0.0040241447]

# %%
print(type(test_x1),strr,test_x1.shape)
test_x1_,  s5 = Fit_transform(test_x1,0,1)
test_y1_,  s6 = Fit_transform(test_y1.reshape(-1,1),0,1)

prediction=model.predict([test_x1_.reshape(test_x1.shape[0],16,1),test_x1_.reshape(test_x1.shape[0],16,1)])

prediction_ = Inverse_transform(prediction, s6)

# 12V-7AH/20HR各代号的含义：
# 1、12V：电池的额定电压。
# 2、7AH：电池的容量，表示该电瓶以7A放电可工作一小时,若以1A放电可工作7小时。
# 3、20HR：建议电池的放电速率为20小时，HR是Hour Rate即倍率的缩写。（20HR）20小时放电率，该电池适于0.35A放电20小时。也就是说不宜大电流放电。

# print(prediction_.shape,test_y1.shape)
# 绘图展示
plt.figure(figsize = (30,10),dpi=50)
plt.plot(test_y1.reshape(-1,1), color = 'red', label = 'Real',linewidth=3)
plt.plot(prediction_, color = 'b', label = 'Predicted',linewidth=1)
plt.title('Battery capacity prediction')
plt.xlabel('sample')
plt.ylabel('Capacity (AH)')
plt.legend()
plt.savefig('NASA-27-%s-testdata.png'%strr)
plt.show()
# Out:
# <class 'numpy.ndarray'> CNN1D_GRU2 (497, 16)

# %%
print(train_x1.shape,strr)
train_x1_,  s7 = Fit_transform(train_x1,0,1)
train_y1_,  s8 = Fit_transform(train_y1.reshape(-1,1),0,1)

# prediction2=model.predict(train_x1_.reshape(train_x1.shape[0],16,1))
prediction2=model.predict([train_x1_.reshape(train_x1.shape[0],16,1),train_x1_.reshape(train_x1.shape[0],16,1)])

prediction_2 = Inverse_transform(prediction2, s8)

# 12V-7AH/20HR各代号的含义：
# 1、12V：电池的额定电压。
# 2、7AH：电池的容量，表示该电瓶以7A放电可工作一小时,若以1A放电可工作7小时。
# 3、20HR：建议电池的放电速率为20小时，HR是Hour Rate即倍率的缩写。（20HR）20小时放电率，该电池适于0.35A放电20小时。也就是说不宜大电流放电。

# print(prediction_.shape,test_y1.shape)
# 绘图展示
plt.figure(figsize = (30,10),dpi=50)
plt.plot(train_y1.reshape(-1,1), color = 'red', label = 'Real',linewidth=3)
plt.plot(prediction_2, color = 'b', label = 'Predicted',linewidth=1)
plt.title('Battery capacity prediction')
plt.xlabel('sample')
plt.ylabel('Capacity (AH)')
plt.legend()
plt.savefig('NASA-27-%s-traindata.png'%strr)
plt.show()
# Out:
# (1427, 16) CNN1D_GRU2

# %%
# sklearn科学计算模块
# keras-sklearn计算相关模块
from keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor,KerasClassifier
# sklearn计算模块
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler,LabelEncoder
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error,classification_report,confusion_matrix
from sklearn.svm import SVC, SVR
# sklearn数据处理模块
from sklearn.datasets import load_digits
from sklearn.model_selection import learning_curve, KFold, GridSearchCV
from sklearn.model_selection import ShuffleSplit,train_test_split,learning_curve
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

def eva_ind(data_gt,data_pre):
    
    gt = data_gt
    pre = data_pre
    pre_mean = np.mean(gt)

    # 获取绝对值误差
    Abs = []
    Abs_error = []
    for i in range(0,len(gt)):
    #     print(i)
        Abs.append(abs(pre[i]-gt[i])) # 绝对误差
        Abs_error.append(abs(gt[i]-pre_mean)) # 标签-预测平均值

    mse = mean_squared_error(pre, gt) # 均方误差
    rmse = np.sqrt(mean_squared_error(pre, gt)) # 根均方误差
    r2_s = r2_score(gt, pre) # 决定系数，反映因变量的全部变异能通过回归关系被自变量解释的比例

    # 平均偏差
    pre_mean_error = np.mean(Abs_error)
    # print(pre_mean_error)
    # 平均误差除以预测集平均值
    relative_error =  pre_mean_error/ pre_mean   

    # 平均绝对值误差（mean_absolute_error）
    mae =  mean_absolute_error(gt,pre)
        # 真实值与
    print(f"测试集均方误差(MSE)：{mse}")
    print(f"测试集根均方误差(RMSE)：{rmse}")
    print(f"测试集平均绝对误差：{mae}")
    print(f"测试集R^2：{r2_s}")
    print(f"测试集相对平均误差：{relative_error*100}%")
print(strr)
print('--- test prediction')
eva_ind(test_y1,prediction_)
print('--- train prediction_')
eva_ind(train_y1,prediction_2)
# Out:
# CNN1D_GRU2
# --- test prediction
# 测试集均方误差(MSE)：0.06885049342753088
# 测试集根均方误差(RMSE)：0.26239377551216964
# 测试集平均绝对误差：0.17582147749486018
# 测试集R^2：0.436066091762528
# 测试集相对平均误差：18.676354072287698%
# --- train prediction_
# 测试集均方误差(MSE)：0.01573655187868798
# 测试集根均方误差(RMSE)：0.12544541394043857
# 测试集平均绝对误差：0.0486259733606156
# 测试集R^2：0.9414663313720077
# 测试集相对平均误差：27.014767290616376%

# %%
"""
27个样本
CNN1D
--- test prediction
测试集均方误差(MSE)：0.040366890131129415
测试集根均方误差(RMSE)：0.20091513166292232
测试集平均绝对误差：0.12540696893287445
测试集R^2：0.6693668123235581
测试集相对平均误差：18.676354072287698%
--- train prediction_
测试集均方误差(MSE)：0.01582276947351823
测试集根均方误差(RMSE)：0.12578859039482965
测试集平均绝对误差：0.0451067472812176
测试集R^2：0.9411456364596407
测试集相对平均误差：27.014767290616376%

LSTM2
--- test prediction
测试集均方误差(MSE)：0.04323706049687612
测试集根均方误差(RMSE)：0.2079352314949925
测试集平均绝对误差：0.11062430123312263
测试集R^2：0.6458581007503204
测试集相对平均误差：18.676354072287698%
--- train prediction_
测试集均方误差(MSE)：0.01734343657450634
测试集根均方误差(RMSE)：0.1316944819440296
测试集平均绝对误差：0.04663090267870282
测试集R^2：0.9354893640520064
测试集相对平均误差：27.014767290616376%



CNN1D_LR
--- test prediction
测试集均方误差(MSE)：0.050989488885775015
测试集根均方误差(RMSE)：0.22580852261545625
测试集平均绝对误差：0.14153322689833436
测试集R^2：0.5823602662099694
测试集相对平均误差：18.676354072287698%
--- train prediction_
测试集均方误差(MSE)：0.016839169785641303
测试集根均方误差(RMSE)：0.1297658267250716
测试集平均绝对误差：0.03485823287644699
测试集R^2：0.9373650344877581
测试集相对平均误差：27.014767290616376%


CNN1D_CNN1D
--- test prediction
测试集均方误差(MSE)：0.06485758870551062
测试集根均方误差(RMSE)：0.25467153100712026
测试集平均绝对误差：0.16838244528969018
测试集R^2：0.4687707864279166
测试集相对平均误差：18.676354072287698%
--- train prediction_
测试集均方误差(MSE)：0.01753803091127434
测试集根均方误差(RMSE)：0.13243123087578074
测试集平均绝对误差：0.045693401432716274
测试集R^2：0.9347655510774063
测试集相对平均误差：27.014767290616376%

CNN1D_LSTM1
--- test prediction
测试集均方误差(MSE)：0.07073097548505354
测试集根均方误差(RMSE)：0.2659529572782629
测试集平均绝对误差：0.18002786663901454
测试集R^2：0.42066362268385094
测试集相对平均误差：18.676354072287698%
--- train prediction_
测试集均方误差(MSE)：0.017937397007850107
测试集根均方误差(RMSE)：0.133930567862046
测试集平均绝对误差：0.055995232279362143
测试集R^2：0.9332800691917666
测试集相对平均误差：27.014767290616376%

CNN1D_GRU1
--- test prediction
测试集均方误差(MSE)：0.07507156320618813
测试集根均方误差(RMSE)：0.27399190354130565
测试集平均绝对误差：0.18629133012897728
测试集R^2：0.38511116001045753
测试集相对平均误差：18.676354072287698%
--- train prediction_
测试集均方误差(MSE)：0.017345250650387348
测试集根均方误差(RMSE)：0.13170136920467967
测试集平均绝对误差：0.040759963388814054
测试集R^2：0.9354826164164822
测试集相对平均误差：27.014767290616376%


CNN1D_LSTM2
--- test prediction
测试集均方误差(MSE)：0.07623181228499039
测试集根均方误差(RMSE)：0.2761010906986613
测试集平均绝对误差：0.18860785050729575
测试集R^2：0.37560790498692487
测试集相对平均误差：18.676354072287698%
--- train prediction_
测试集均方误差(MSE)：0.01393013460766462
测试集根均方误差(RMSE)：0.11802599123779736
测试集平均绝对误差：0.034019644697834056
测试集R^2：0.948185479935243
测试集相对平均误差：27.014767290616376%


CNN1D_GRU2
--- test prediction
测试集均方误差(MSE)：0.06885049342753088
测试集根均方误差(RMSE)：0.26239377551216964
测试集平均绝对误差：0.17582147749486018
测试集R^2：0.436066091762528
测试集相对平均误差：18.676354072287698%
--- train prediction_
测试集均方误差(MSE)：0.01573655187868798
测试集根均方误差(RMSE)：0.12544541394043857
测试集平均绝对误差：0.0486259733606156
测试集R^2：0.9414663313720077
测试集相对平均误差：27.014767290616376%


"""




"""
LSTM2-(05-018)-容量
--- test prediction
测试集均方误差(MSE)：0.00023966289652662987
测试集根均方误差(RMSE)：0.01548104959383019
测试集平均绝对误差：0.010501952931301914
测试集R^2：0.9669668009565185
测试集相对平均误差：5.360328947805525%
--- train prediction
测试集均方误差(MSE)：0.0003288080711828095
测试集根均方误差(RMSE)：0.01813306568627626
测试集平均绝对误差：0.010693315171653265
测试集R^2：0.9883091397802551
测试集相对平均误差：9.055994015555727%

CNN1D-(05-018)-容量
--- test prediction
测试集均方误差(MSE)：0.0002323281231515903
测试集根均方误差(RMSE)：0.015242313576081233
测试集平均绝对误差：0.010110452687513542
测试集R^2：0.9679777669105647
测试集相对平均误差：5.360328947805525%
--- train prediction
测试集均方误差(MSE)：0.00033319614608990847
测试集根均方误差(RMSE)：0.01825366116947251
测试集平均绝对误差：0.012247011950276181
测试集R^2：0.9881531205858719
测试集相对平均误差：9.055994015555727%

GRU3-(05-015)-容量
--- test prediction
测试集均方误差(MSE)：0.0002287943351844333
测试集根均方误差(RMSE)：0.015125949067229907
测试集平均绝对误差：0.009713810179947689
测试集R^2：0.9684648357184125
测试集相对平均误差：5.360328947805525%
--- train prediction_
测试集均方误差(MSE)：0.0004069002326348896
测试集根均方误差(RMSE)：0.02017176820794076
测试集平均绝对误差：0.01056620091093283
测试集R^2：0.9855325517831606
测试集相对平均误差：9.055994015555727%


CNN1D+CNN1D-
--- test prediction
测试集均方误差(MSE)：0.00024393199378423903
测试集根均方误差(RMSE)：0.015618322374193683
测试集平均绝对误差：0.009766953932471182
测试集R^2：0.9663783830516598
测试集相对平均误差：5.360328947805525%
--- train prediction
测试集均方误差(MSE)：0.0003575179766585768
测试集根均方误差(RMSE)：0.01890814577526249
测试集平均绝对误差：0.009694251588587357
测试集R^2：0.987288351298294
测试集相对平均误差：9.055994015555727%

CNN1D+LR-
--- test prediction
测试集均方误差(MSE)：0.00026620054576812494
测试集根均方误差(RMSE)：0.01631565339691074
测试集平均绝对误差：0.011260282532168767
测试集R^2：0.9633090656030489
测试集相对平均误差：5.360328947805525%
--- train prediction
测试集均方误差(MSE)：0.0004270440649665279
测试集根均方误差(RMSE)：0.020665044518861503
测试集平均绝对误差：0.012640350206947244
测试集R^2：0.9848163323569402
测试集相对平均误差：9.055994015555727%

CNN1D+LSTM1-
--- test prediction
测试集均方误差(MSE)：0.0002805039129130459
测试集根均方误差(RMSE)：0.016748251040423472
测试集平均绝对误差：0.010363606223771624
测试集R^2：0.961337604935846
测试集相对平均误差：5.360328947805525%
--- train prediction
测试集均方误差(MSE)：0.0003431047203075095
测试集根均方误差(RMSE)：0.018523086144255484
测试集平均绝对误差：0.009653881126639093
测试集R^2：0.9878008185400667
测试集相对平均误差：9.055994015555727%

CNN1D+GRU1-
--- test prediction
测试集均方误差(MSE)：0.0002606825293596219
测试集根均方误差(RMSE)：0.01614566596209713
测试集平均绝对误差：0.009745423539555657
测试集R^2：0.9640696244421056
测试集相对平均误差：5.360328947805525%
--- train prediction
测试集均方误差(MSE)：0.00040735209855444253
测试集根均方误差(RMSE)：0.020182965554012187
测试集平均绝对误差：0.011189999739052868
测试集R^2：0.9855164855677403
测试集相对平均误差：9.055994015555727%

CNN1D+LSTM2-
--- test prediction
测试集均方误差(MSE)：0.00024193514835970138
测试集根均方误差(RMSE)：0.015554264635774376
测试集平均绝对误差：0.01070765969308011
测试集R^2：0.9666536121059848
测试集相对平均误差：5.360328947805525%
--- train prediction
测试集均方误差(MSE)：0.0003675522936159113
测试集根均方误差(RMSE)：0.019171653387642686
测试集平均绝对误差：0.011846027286123674
测试集R^2：0.9869315784352471
测试集相对平均误差：9.055994015555727%


CNN1D+GRU2-
--- test prediction
测试集均方误差(MSE)：0.00029627795194351263
测试集根均方误差(RMSE)：0.017212726452933383
测试集平均绝对误差：0.010893999484499798
测试集R^2：0.9591634387275395
测试集相对平均误差：5.360328947805525%
--- train prediction
测试集均方误差(MSE)：0.00025712257065268015
测试集根均方误差(RMSE)：0.016035041959804163
测试集平均绝对误差：0.00959326131614557
测试集R^2：0.9908579372093007
测试集相对平均误差：9.055994015555727%


"""
# Out:
# '\nLSTM2-(05-018)-容量\n--- test prediction\n测试集均方误差(MSE)：0.00023966289652662987\n测试集根均方误差(RMSE)：0.01548104959383019\n测试集平均绝对误差：0.010501952931301914\n测试集R^2：0.9669668009565185\n测试集相对平均误差：5.360328947805525%\n--- train prediction\n测试集均方误差(MSE)：0.0003288080711828095\n测试集根均方误差(RMSE)：0.01813306568627626\n测试集平均绝对误差：0.010693315171653265\n测试集R^2：0.9883091397802551\n测试集相对平均误差：9.055994015555727%\n\nCNN1D-(05-018)-容量\n--- test prediction\n测试集均方误差(MSE)：0.0002678508003343722\n测试集根均方误差(RMSE)：0.016366147999281083\n测试集平均绝对误差：0.011092402991777925\n测试集R^2：0.96308160783487\n测试集相对平均误差：5.360328947805525%\n--- train prediction\n测试集均方误差(MSE)：0.00043120200364261816\n测试集根均方误差(RMSE)：0.020765404008653867\n测试集平均绝对误差：0.011082255870632522\n测试集R^2：0.9846684957187166\n测试集相对平均误差：9.055994015555727%\n\nGRU3-(05-015)-容量\n--- test prediction\n测试集均方误差(MSE)：0.00025840616280380985\n测试集根均方误差(RMSE)：0.016075016727948057\n测试集平均绝对误差：0.01078761913100423\n测试集R^2：0.964383380432807\n测试集相对平均误差：5.360328947805525%\n--- train prediction\n测试集均方误差(MSE)：0.0004330534570875633\n测试集根均方误差(RMSE)：0.02080993649888349\n测试集平均绝对误差：0.010782926175881252\n测试集R^2：0.984602666788939\n测试集相对平均误差：9.055994015555727%\n\n\nCNN1D+CNN1D-\n--- test prediction\n测试集均方误差(MSE)：0.00024393199378423903\n测试集根均方误差(RMSE)：0.015618322374193683\n测试集平均绝对误差：0.009766953932471182\n测试集R^2：0.9663783830516598\n测试集相对平均误差：5.360328947805525%\n--- train prediction\n测试集均方误差(MSE)：0.0003575179766585768\n测试集根均方误差(RMSE)：0.01890814577526249\n测试集平均绝对误差：0.009694251588587357\n测试集R^2：0.987288351298294\n测试集相对平均误差：9.055994015555727%\n\nCNN1D+LR-\n--- test prediction\n测试集均方误差(MSE)：0.00026620054576812494\n测试集根均方误差(RMSE)：0.01631565339691074\n测试集平均绝对误差：0.011260282532168767\n测试集R^2：0.9633090656030489\n测试集相对平均误差：5.360328947805525%\n--- train prediction\n测试集均方误差(MSE)：0.0004270440649665279\n测试集根均方误差(RMSE)：0.020665044518861503\n测试集平均绝对误差：0.012640350206947244\n测试集R^2：0.9848163323569402\n测试集相对平均误差：9.055994015555727%\n\nCNN1D+LSTM1-\n--- test prediction\n测试集均方误差(MSE)：0.0002805039129130459\n测试集根均方误差(RMSE)：0.016748251040423472\n测试集平均绝对误差：0.010363606223771624\n测试集R^2：0.961337604935846\n测试集相对平均误差：5.360328947805525%\n--- train prediction\n测试集均方误差(MSE)：0.0003431047203075095\n测试集根均方误差(RMSE)：0.018523086144255484\n测试集平均绝对误差：0.009653881126639093\n测试集R^2：0.9878008185400667\n测试集相对平均误差：9.055994015555727%\n\nCNN1D+GRU1-\n--- test prediction\n测试集均方误差(MSE)：0.0002606825293596219\n测试集根均方误差(RMSE)：0.01614566596209713\n测试集平均绝对误差：0.009745423539555657\n测试集R^2：0.9640696244421056\n测试集相对平均误差：5.360328947805525%\n--- train prediction\n测试集均方误差(MSE)：0.00040735209855444253\n测试集根均方误差(RMSE)：0.020182965554012187\n测试集平均绝对误差：0.011189999739052868\n测试集R^2：0.9855164855677403\n测试集相对平均误差：9.055994015555727%\n\nCNN1D+LSTM2-\n--- test prediction\n测试集均方误差(MSE)：0.00024193514835970138\n测试集根均方误差(RMSE)：0.015554264635774376\n测试集平均绝对误差：0.01070765969308011\n测试集R^2：0.9666536121059848\n测试集相对平均误差：5.360328947805525%\n--- train prediction\n测试集均方误差(MSE)：0.0003675522936159113\n测试集根均方误差(RMSE)：0.019171653387642686\n测试集平均绝对误差：0.011846027286123674\n测试集R^2：0.9869315784352471\n测试集相对平均误差：9.055994015555727%\n\n\nCNN1D+GRU2-\n--- test prediction\n测试集均方误差(MSE)：0.00029627795194351263\n测试集根均方误差(RMSE)：0.017212726452933383\n测试集平均绝对误差：0.010893999484499798\n测试集R^2：0.9591634387275395\n测试集相对平均误差：5.360328947805525%\n--- train prediction\n测试集均方误差(MSE)：0.00025712257065268015\n测试集根均方误差(RMSE)：0.016035041959804163\n测试集平均绝对误差：0.00959326131614557\n测试集R^2：0.9908579372093007\n测试集相对平均误差：9.055994015555727%\n\n\n'

# %%
def build_sequences(text, window_size):
    #text:list of capacity
    x, y = [],[]
    for i in range(len(text) - window_size):  # 【window_size:-1】
        sequence = text[i:i+window_size]      # 特征
        target = text[i+1:i+1+window_size]    # 标签,延后的序列。。。？？？

        x.append(sequence)
        y.append(target)
        
    return np.array(x), np.array(y)


# 留一评估：一组数据为测试集，其他所有数据全部拿来训练
def get_train_test(data_dict, name, window_size=8):
    
    # 该部分是选取一个step_time序列为测试集
    data_sequence=data_dict[name][1]
    train_data, test_data = data_sequence[:window_size+1], data_sequence[window_size+1:]  # 且分出训练数据和测试数据
#     print(len(data_dict),len(data_sequence),len(train_data),len(test_data))
    train_x, train_y = build_sequences(text=train_data, window_size=window_size)   # 制作数据集特征和标签
#     print(len(train_x[0]),len(train_y[0]))
    
    # 余下数据生成训练集
    for k, v in data_dict.items():  # 返回可遍历的(键, 值) 元组数组，然后便利
        if k != name:
            data_x, data_y = build_sequences(text=v[1], window_size=window_size)
            train_x, train_y = np.r_[train_x, data_x], np.r_[train_y, data_y]
                            # np.r_：是按列连接两个矩阵，就是把两矩阵上下相加，要求列数相等，类似于pandas中的concat()。
                            # np.c_：是按行连接两个矩阵，就是把两矩阵左右相加，要求行数相等，类似于pandas中的merge()。
    return train_x, train_y, list(train_data), list(test_data)

# 相对误差
def relative_error(y_test, y_predict, threshold):
    true_re, pred_re = len(y_test), 0
    for i in range(len(y_test)-1):
        if y_test[i] <= threshold >= y_test[i+1]:
            true_re = i - 1
            break
    for i in range(len(y_predict)-1):
        if y_predict[i] <= threshold:
            pred_re = i - 1
            break
    return abs(true_re - pred_re)/true_re


def evaluation(y_test, y_predict):
    mae = mean_absolute_error(y_test, y_predict)
    mse = mean_squared_error(y_test, y_predict)
    rmse = sqrt(mean_squared_error(y_test, y_predict))
    return mae, rmse
    
    
def setup_seed(seed):
    # 设置随机数种子，为所有的模式提供固定随机情况，使得实验课复现
    np.random.seed(seed)  # Numpy module.
    random.seed(seed)  # Python random module.
    os.environ['PYTHONHASHSEED'] = str(seed) # 为了禁止hash随机化，使得实验可复现。
    torch.manual_seed(seed) # 为CPU设置随机种子
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed) # 为当前GPU设置随机种子
        torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU，为所有GPU设置随机种子
        torch.backends.cudnn.benchmark = False
        torch.backends.cudnn.deterministic = True

# %%
class Net(nn.Module):
    def __init__(self, input_size, hidden_dim, num_layers, n_class=1, mode='LSTM'):
        super(Net, self).__init__()
        self.hidden_dim = hidden_dim
        self.cell = nn.LSTM(input_size=input_size, hidden_size=hidden_dim, num_layers=num_layers, batch_first=True)
        if mode == 'GRU':
            self.cell = nn.GRU(input_size=input_size, hidden_size=hidden_dim, num_layers=num_layers, batch_first=True)
        elif mode == 'RNN':
            self.cell = nn.RNN(input_size=input_size, hidden_size=hidden_dim, num_layers=num_layers, batch_first=True)
        self.linear = nn.Linear(hidden_dim, n_class)
 
    def forward(self, x):           # x shape: (batch_size, seq_len, input_size)
        out, _ = self.cell(x) 
        out = out.reshape(-1, self.hidden_dim)
        out = self.linear(out)      # out shape: (batch_size, n_class=1)
        return out

# %%
from torchsummary import summary

def tain(lr=0.001, feature_size=16, hidden_dim=128, num_layers=2, 
         weight_decay=0.0, mode = 'LSTM', EPOCH=1000, seed=0):
    # Battery_list ： 样本列表
    # Battery      ：【序号，电池容量】

    
    score_list, result_list = [], []
    for i in range(4):
        name = Battery_list[i]  # 样本列表
        # 划分数据集
        train_x, train_y, train_data, test_data = get_train_test(capacity, name, window_size=feature_size)
        train_size = len(train_x)
        print('sample size: {}'.format(train_size))

        setup_seed(seed)
        model = Net(input_size=feature_size, hidden_dim=hidden_dim, num_layers=num_layers, mode=mode)
        model = model.to(device)
#         net11 = model
#         summary(net11)

        optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        criterion = nn.MSELoss()

        test_x = train_data.copy()  # 生成的测试集
        loss_list, y_ = [0], []     # 声明loss和pre容器
        mae, rmse, re = 1, 1, 1     # 初始化评价指标
        score_, score = 1,1         # 初始化评价列表
        
        for epoch in range(EPOCH):
            # 数据处理
            X = np.reshape(train_x/Rated_Capacity,(-1, 1, feature_size)).astype(np.float32)#(batch_size, seq_len, input_size)
            y = np.reshape(train_y[:,-1]/Rated_Capacity,(-1,1)).astype(np.float32)# shape 为 (batch_size, 1)
            X, y = torch.from_numpy(X).to(device), torch.from_numpy(y).to(device)
            
            output= model(X)                   # 预测结果
            output = output.reshape(-1, 1)
            loss = criterion(output, y)        # 计算loss
            optimizer.zero_grad()              # clear gradients for this training step
            loss.backward()                    # backpropagation, compute gradients
            optimizer.step()                   # apply gradients

            if (epoch + 1)%100 == 0:
                test_x = train_data.copy()    #每100次重新预测一次
                point_list = []
                while (len(test_x) - len(train_data)) < len(test_data):
                    x = np.reshape(np.array(test_x[-feature_size:])/Rated_Capacity,(-1, 1, feature_size)).astype(np.float32)
                    x = torch.from_numpy(x).to(device)                 # shape: (batch_size, 1, input_size)
                    
                    pred = model(x)
#                     print('???????????????????????/',pred.shape)
                    next_point = pred.data.cpu().numpy()[0,0] * Rated_Capacity
                    test_x.append(next_point)                          #测试值加入原来序列用来继续预测下一个点
                    point_list.append(next_point)                     #保存输出序列最后一个点的预测值
                y_.append(point_list)                                 #保存本次预测所有的预测值
                loss_list.append(loss)
                mae, rmse = evaluation(y_test=test_data, y_predict=y_[-1])
                re = relative_error(y_test=test_data, y_predict=y_[-1], threshold=Rated_Capacity*0.7)
                print('epoch:{:<2d} | loss:{:<6.4f} | MAE:{:<6.4f} | RMSE:{:<6.4f} | RE:{:<6.4f}'.format(epoch, loss, mae, rmse, re))
            score = [re, mae, rmse]
            if (loss < 1e-3) and (score_[0] < score[0]):
                break
            score_ = score.copy()
            
        score_list.append(score_)
        result_list.append(y_[-1])
    return score_list, result_list,loss_list,model

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda:0

# %%
window_size = 16     # step_time
EPOCH = 1000         
lr = 0.001           # learning rate
hidden_dim = 256     # 隐层维度，神经元个数
num_layers = 2       # 隐层层数
weight_decay = 0.0   # 学习率衰减
mode = 'LSTM'        # RNN, LSTM, GRU
Rated_Capacity = 2.0 # 额定容量
 
# 进行十次随机数固定实验，并输出loss\MAE\RMSE\RE
SCORE = []
RES = []
LOSS = []
seed = 0
# for seed in range(2):
#     print('seed: ', seed)
#     score_list, res, loss_list = tain(lr=lr, feature_size=window_size, hidden_dim=hidden_dim, num_layers=num_layers, 
#                          weight_decay=weight_decay, mode=mode, EPOCH=EPOCH, seed=seed)
#     print('------------------------------------------------------------------')
#     for s in score_list:  
#         SCORE.append(s)
# #     if seed == 2: LOSS.append(loss_list)
# # plt.plot(res, 'b', label='loss')


score_list, res, loss_list, model = tain(lr=lr, feature_size=window_size, hidden_dim=hidden_dim, num_layers=num_layers, 
                         weight_decay=weight_decay, mode=mode, EPOCH=EPOCH, seed=seed)
print('------------------------------------------------------------------')
for s in score_list:  
    SCORE.append(s)

mlist = ['re', 'mae', 'rmse']
for i in range(3):
    s = [line[i] for line in SCORE] 
    print(mlist[i] + ' mean: {:<6.4f}'.format(np.mean(np.array(s)))) # 输出均值
print('------------------------------------------------------------------')
print('------------------------------------------------------------------')
# Out:
# 4 168 17 151
# 16 16
# sample size: 421
# epoch:99 | loss:0.0007 | MAE:0.1099 | RMSE:0.1247 | RE:1.0000
# epoch:199 | loss:0.0004 | MAE:0.0914 | RMSE:0.1031 | RE:1.0000
# epoch:299 | loss:0.0003 | MAE:0.0705 | RMSE:0.0830 | RE:0.0566
# epoch:399 | loss:0.0002 | MAE:0.0563 | RMSE:0.0702 | RE:0.0755
# 4 168 17 151
# 16 16
# sample size: 421
# epoch:99 | loss:0.0005 | MAE:0.1216 | RMSE:0.1448 | RE:1.0000
# epoch:199 | loss:0.0004 | MAE:0.1183 | RMSE:0.1418 | RE:1.0000
# epoch:299 | loss:0.0002 | MAE:0.1050 | RMSE:0.1253 | RE:1.0000
# epoch:399 | loss:0.0002 | MAE:0.1055 | RMSE:0.1217 | RE:1.0000
# epoch:499 | loss:0.0001 | MAE:0.1188 | RMSE:0.1325 | RE:0.5889
# epoch:599 | loss:0.0001 | MAE:0.1353 | RMSE:0.1486 | RE:0.6000
# 4 168 17 151
# 16 16
# sample size: 421
# epoch:99 | loss:0.0007 | MAE:0.1338 | RMSE:0.1542 | RE:1.0000
# epoch:199 | loss:0.0004 | MAE:0.1168 | RMSE:0.1289 | RE:0.1258
# epoch:299 | loss:0.0003 | MAE:0.1216 | RMSE:0.1247 | RE:0.3444
# 4 132 17 115
# 16 16
# sample size: 457
# epoch:99 | loss:0.0007 | MAE:0.0566 | RMSE:0.0665 | RE:1.0000
# epoch:199 | loss:0.0004 | MAE:0.0471 | RMSE:0.0575 | RE:1.0000
# epoch:299 | loss:0.0002 | MAE:0.0347 | RMSE:0.0416 | RE:0.3974
# epoch:399 | loss:0.0002 | MAE:0.0322 | RMSE:0.0384 | RE:0.2308
# epoch:499 | loss:0.0002 | MAE:0.0351 | RMSE:0.0404 | RE:0.1923
# epoch:599 | loss:0.0002 | MAE:0.0370 | RMSE:0.0419 | RE:0.1795
# epoch:699 | loss:0.0002 | MAE:0.0379 | RMSE:0.0429 | RE:0.1795
# epoch:799 | loss:0.0002 | MAE:0.0379 | RMSE:0.0428 | RE:0.1795
# epoch:899 | loss:0.0002 | MAE:0.0380 | RMSE:0.0429 | RE:0.1795
# epoch:999 | loss:0.0002 | MAE:0.0381 | RMSE:0.0430 | RE:0.1795
# ------------------------------------------------------------------
# re mean: 0.2377
# mae mean: 0.0860
# rmse mean: 0.0969
# ------------------------------------------------------------------
# ------------------------------------------------------------------
