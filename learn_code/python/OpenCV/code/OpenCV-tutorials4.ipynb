# %% [markdown]
# # Basic Operations on Images
# Access pixel values and modify them
#
# Access image properties
#
# Setting Region of Image (ROI)
#
# Splitting and Merging images

# %% [markdown]
# ## 访问及修改像素值

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt


img = cv.imread('bizhi1.jpg')

plt.imshow(img)
plt.show()
# cv.imwrite('bizhi3.jpg',img)
print(img.shape) #获取图像的形状，返回值是一个包含行数、列数、通道数的元组
print(img.size)  #获得图像的像素数目。
print(img.dtype)  #获得图像的数据类型。
# Out:
# (1080, 1920, 3)
# 6220800
# uint8

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt


img = cv.imread('messi0.jpg')
print(img.shape) #获取图像的形状，返回值是一个包含行数、列数、通道数的元组
print(img.size)  #获得图像的像素数目。
print(img.dtype)  #获得图像的数据类型。

# px = img[100,100]
# print(px)

# blue = img[100,100,0]
# print(blue)

img[100,100] = [255,255,255]
print(img[100,100])
# Out:
# (280, 450, 3)
# 378000
# uint8
# [255 255 255]

# %% [markdown]
# ##  array.item() and array.itemset()
# 访问特定像素数，修改特定像素数

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('messi0.jpg')

# accessing RED value
img.item(10,10,2)
# Out:
# 50

# %%
# modifying RED value
img.itemset((10,10,2),100)
img.item(10,10,2)
# Out:
# 100

# %% [markdown]
# ## 访问图像属性img.shape\.size\.dttype
# 图像属性包括行数，列数和通道数，图像数据类型，像素数等。
#
# 吐过图像是灰阶，则反馈的元祖仅包含行数和列数

# %%
print('img的行列通道数：',img.shape)
print('img的pixel总数：',img.size)
print('img数据类型：',img.dtype)  #数据类型非常重要
# Out:
# img的行列通道数： (280, 450, 3)
# img的pixel总数： 378000
# img数据类型： uint8

# %% [markdown]
# # ROI（setting region of images）

# %%
#提取足球复制到另一个区域
# boll = img[280:340,330:390]
# img[273:333,100:160] = boll
boll = img[220:280,270:330]  #选定复制区
img[220:280,80:140] = boll    #选定粘贴区
#根据自己的图片微调
plt.imshow(img)
plt.show()

# %% [markdown]
# ## 拆分颜色通道，必要时候合并

# %% [markdown]
# 1. cv.split()
#
# b,g,r = cv.split(img) #拆分
#
# img = cv.merge((b,g,r)) #合并
#
# 2.numpy方式
#
# b = img[:,:,0] #拆分b颜色通道，0：b，1：g,2:r
#
# img[:,:,2] = 0  #令所有的r红色色素为0
#
# 多用numpy方式

# %% [markdown]
# ## 填充边框 cv2.copyMakeBorder()
# src-输入图像
#
# 顶部，底部，左侧，右侧-相应方向上的边框宽度（以像素数为单位）
#
# borderType-定义要添加哪种边框的标志。
#
# 它可以是以下类型：
#
# cv2.BORDER_CONSTANT-添加恒定的彩色边框。该值应作为下一个参数给出。
#
# cv2.BORDER_REFLECT-边框将是边框元素的镜像，如下所示：fedcba | abcdefgh | hgfedcb
#
# cv2.BORDER_REFLECT_101或cv2.BORDER_DEFAULT-与上述相同，但略有变化，例如：gfedcb | abcdefgh | gfedcba
#
# cv2.BORDER_REPLICATE-最后一个元素被复制，像这样：aaaaaa | abcdefgh | hhhhhhh
#
# cv2.BORDER_WRAP-无法解释，看起来像这样：cdefgh | abcdefgh | abcdefg
#
# value-边框类型为cv2.BORDER_CONSTANT时边框的颜色

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

BLUE = [255,0,0]
img1 = cv.imread('opencv-logo-white.png')

replicate = cv.copyMakeBorder(img1,10,10,10,10,cv.BORDER_REPLICATE)
reflect = cv.copyMakeBorder(img1,10,10,10,10,cv.BORDER_REFLECT)
reflect101 = cv.copyMakeBorder(img1,10,10,10,10,cv.BORDER_REFLECT_101)
wrap = cv.copyMakeBorder(img1,10,10,10,10,cv.BORDER_WRAP)
constant= cv.copyMakeBorder(img1,10,10,10,10,cv.BORDER_CONSTANT,value=BLUE)

plt.subplot(231),plt.imshow(img1,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')

print('注意：/n cv2通道为BGR因此，蓝色和红色位置互调')
plt.show()
# Out:
# 注意：/n cv2通道为BGR因此，蓝色和红色位置互调

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

BLUE = [255,0,0]
BLUE2 = [0,0,255]
img1 = cv.imread('messi0.jpg')

replicate = cv.copyMakeBorder(img1,50,50,50,50,cv.BORDER_REPLICATE)
reflect = cv.copyMakeBorder(img1,50,50,50,50,cv.BORDER_REFLECT)
reflect101 = cv.copyMakeBorder(img1,50,50,50,50,cv.BORDER_REFLECT_101)
wrap = cv.copyMakeBorder(img1,50,50,50,50,cv.BORDER_WRAP)
constant= cv.copyMakeBorder(img1,50,50,50,50,cv.BORDER_CONSTANT,value=BLUE)

plt.subplot(231),plt.imshow(img1,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')

print('注意：/n cv2通道为BGR因此，蓝色和红色位置互调')
plt.show()
# Out:
# 注意：/n cv2通道为BGR因此，蓝色和红色位置互调
