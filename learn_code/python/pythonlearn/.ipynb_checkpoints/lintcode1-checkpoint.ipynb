# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 简单计算器1
class Calculator:

    def calculator(self,a,operator,b):
        a = input(a)
        b = input(b)
        if operator == '+':
            return print(a + b)
        elif operator == '-':
            return print(a - b)
        elif operator == '*':
            return print(a * b)
        elif operator == '/':
            return print(a / b)

# int1,int2,operator = Calculator(a,operator,b)
x = Calculator()

a = input('请输入a：')
b = input('请输入b：')
operator = input('运算符为：')
x.calculator()
print('您的运算结果是：',x)
# Out:
# 请输入a：2
# 请输入b：3
# 运算符为：-
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-7b50d0f650e0> in <module>
#      20 b = input('请输入b：')
#      21 operator = input('运算符为：')
# ---> 22 x.calculator()
#      23 print('您的运算结果是：',x)
#      24
#
# TypeError: calculator() missing 3 required positional arguments: 'a', 'operator', and 'b'
